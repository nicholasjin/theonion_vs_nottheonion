# %% [markdown]
# # `spaCy`
#
# In this notebook, we explore using the python library `spacy` to enhance our analysis.
#
# We ran into implementation issues, so there is no useful modelling in this notebook. Feel free to skip forward to the next.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import pickle

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.naive_bayes import MultinomialNB, GaussianNB
# Import CountVectorizer and TFIDFVectorizer from feature_extraction.text.
from sklearn.feature_extraction.text import CountVectorizer,\
                                            TfidfVectorizer


from sklearn.base import TransformerMixin

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer
from nltk.stem.porter import PorterStemmer

# %%
def save_obj(obj, filename):
    with open(filename + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(filename):
    with open(filename + '.pkl', 'rb') as f:
        return pickle.load(f)

# %%
DIR = "C:\\Users\\AzNsAnTaGiN\\DSI\\Projects\\project_3\\data\\"
FILE1 = "theonion"
FILE2 = "nottheonion"
FILE3 = "onionheadlines"

# %% [markdown]
# # Data Import

# %%
X_theonion = load_obj(DIR+FILE1+"_df_clean")
X_nottheonion = load_obj(DIR+FILE2+"_df_clean")

# %%
X_theonion["is_onion"] = 1
X_nottheonion["is_onion"] = -1

# %% [markdown]
# # Tokenizing with `spacy`
#
# We follow along with the tutorial found here
# https://www.dataquest.io/blog/tutorial-text-classification-in-python-using-spacy/

# %%
import spacy

from spacy.lang.en import English
from spacy.lang.en.stop_words import STOP_WORDS
import en_core_web_sm, en_core_web_lg

import string

# %%
nlp_sm = en_core_web_sm.load()
nlp_lg = en_core_web_lg.load()

# %% [markdown]
# The following code, which merges tokens that are part of the same spacy `entity`, comes from https://stackoverflow.com/questions/54640715/tokenizing-named-entities-in-spacy
#
# Unfortunately, we can't get it to work, which is a shame, but we'll press on without it.

# %%
# class EntityRetokenizeComponent:
#   def __init__(self, nlp):
#     pass
#   def __call__(self, doc):
#     with doc.retokenize() as retokenizer:
#         for ent in doc.ents:
#             retokenizer.merge(doc[ent.start:ent.end], attrs={"LEMMA": str(doc[ent.start:ent.end])})
#     return doc

# retokenizer = EntityRetokenizeComponent(nlp_lg) 
# nlp_lg.add_pipe(retokenizer, name='merge_phrases', last=True)

# # doc = nlp_lg("German Chancellor Angela Merkel and US President Barack Obama "
# #           "converse in the Oval Office inside the White House in Washington, D.C.")

# # [tok for tok in doc]

# %% [markdown]
# The following code, which implements some lemmatization, comes from https://www.dataquest.io/blog/tutorial-text-classification-in-python-using-spacy/

# %%
stop_words = spacy.lang.en.stop_words.STOP_WORDS
puntuations = string.punctuation
nlp=spacy.load("en_core_web_sm")
parser = English()

def spacy_tokenizer(sentence):
    mytokens = parser(sentence)
    
    #lemmatize
    mytokens = [ word.lemma_.lower().strip() if word.lemma_ != "-PRON-" else word.lower_ for word in mytokens]
    
    #prune stopwords and punctuation
    mytokens = [word for word in mytokens if word not in stop_words and word not in puntuations]


class predictors(TransformerMixin):
    def transform(self, X, **transform_params):
        # Cleaning Text
        return [clean_text(text) for text in X]

    def fit(self, X, y=None, **fit_params):
        return self

    def get_params(self, deep=True):
        return {}
    
def clean_text(text):
    return text.strip().lower()

# %% [markdown]
# Now in the future we can call our methods with `tokenizer = spacy_tokenizer`, and add a `("cleaner", predictors())` preprocessing step to our pipeline.

# %%
X_theonion["title"].head(1)
# Out:
# id
# 79mcv    Microsoft Ad Campaign Crashing Nations Televis...
# Name: title, dtype: object

# %% [markdown]
# # Taking spacy for a spin
# Now that we have a preprocessing workflow, let's see if it improves anything.

# %% [markdown]
# ## Generating our samples and holdout

# %%
N=4000
X_theonion_shuffled = X_theonion.sample(len(X_theonion))
theonion_sample = X_theonion_shuffled.head(N)
theonion_holdout = X_theonion_shuffled.tail(len(X_theonion_shuffled) - N)

X_nottheonion_shuffled = X_nottheonion.sample(len(X_nottheonion))
nottheonion_sample = X_nottheonion_shuffled.head(N)
nottheonion_holdout = X_nottheonion_shuffled.tail(len(X_nottheonion_shuffled)-N)
X_sample = pd.concat([theonion_sample, nottheonion_sample])
X = pd.concat([X_theonion, X_nottheonion])

# %% [markdown]
# # TF-IDF + Logistic Regression

# %%
X_train, X_test, y_train, y_test = train_test_split(X_sample["title"], X_sample["is_onion"])
pipe = Pipeline([
    ("cleaner", predictors()),
    ("tfidf", TfidfVectorizer(tokenizer=spacy_tokenizer)),
    ("logreg", LogisticRegressionCV(Cs=np.logspace(-2,2,100), max_iter=1000))
])
pipe.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-2cf17a51f506> in <module>
#       5     ("logreg", LogisticRegressionCV(Cs=np.logspace(-2,2,100), max_iter=1000))
#       6 ])
# ----> 7 pipe.fit(X_train, y_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     348             This estimator
#     349         """
# --> 350         Xt, fit_params = self._fit(X, y, **fit_params)
#     351         with _print_elapsed_time('Pipeline',
#     352                                  self._log_message(len(self.steps) - 1)):
#
# ~\Anaconda3\lib\site-packages\sklearn\pipeline.py in _fit(self, X, y, **fit_params)
#     313                 message_clsname='Pipeline',
#     314                 message=self._log_message(step_idx),
# --> 315                 **fit_params_steps[name])
#     316             # Replace the transformer of the step with the fitted
#     317             # transformer. This is necessary when loading the transformer
#
# ~\Anaconda3\lib\site-packages\joblib\memory.py in __call__(self, *args, **kwargs)
#     353
#     354     def __call__(self, *args, **kwargs):
# --> 355         return self.func(*args, **kwargs)
#     356
#     357     def call_and_shelve(self, *args, **kwargs):
#
# ~\Anaconda3\lib\site-packages\sklearn\pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     726     with _print_elapsed_time(message_clsname, message):
#     727         if hasattr(transformer, 'fit_transform'):
# --> 728             res = transformer.fit_transform(X, y, **fit_params)
#     729         else:
#     730             res = transformer.fit(X, y, **fit_params).transform(X)
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in fit_transform(self, raw_documents, y)
#    1857         """
#    1858         self._check_params()
# -> 1859         X = super().fit_transform(raw_documents)
#    1860         self._tfidf.fit(X)
#    1861         # X is already a transformed view of raw_documents so
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in fit_transform(self, raw_documents, y)
#    1218
#    1219         vocabulary, X = self._count_vocab(raw_documents,
# -> 1220                                           self.fixed_vocabulary_)
#    1221
#    1222         if self.binary:
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in _count_vocab(self, raw_documents, fixed_vocab)
#    1129         for doc in raw_documents:
#    1130             feature_counter = {}
# -> 1131             for feature in analyze(doc):
#    1132                 try:
#    1133                     feature_idx = vocabulary[feature]
#
# TypeError: 'NoneType' object is not iterable

# %%
pipe.transform(X_train)
# Out:
# ['new study finds simple way to inoculate teens against junk food marketing',
#  'man with backed-up shower drain enjoys luxurious foot soak',
#  'couple catches massive 809-pound gator',
#  'teen commits suicide after cops crack facebook joke',
#  'officials: woman passed gas, then pulled knife on offended man',
#  '‘subversive’ icon peppa pig hogs the headlines in china',
#  'transaging: father leaves family to live as a 6 year old girl',
#  'trump promises government will continue to fund all essential mar-a-lago staff during shutdown',
#  'ni no kuni: remastering done right, but gameplay is marred by my newborn sons constantly screaming',
#  "oxford student refuses to tip white waitress until 'land is returned' in south africa",
#  'alas, that japanese astronaut did not really grow 9cm in space',
#  "wealthy l.a. schools' vaccination rates are as low as south sudan's",
#  'kid who mowed white house lawn to flip on trump',
#  'this cryptocurrency mining rig with two radeon rx 580 cards doubles as a heater',
#  'mirena releases new 10-blade intrauterine sperm shredder',
#  'aging mother threatens to get some sperm and shoot it in daughters womb herself if she doesnt hurry the fuck up',
#  'tips for reducing heartburn',
#  'sex act to ‘de-stress’ aquarium dolphins is abuse, activist says',
#  'pooey puitton sues louis vuitton',
#  'xbox one trolls trick people into using bing',
#  'leonardo dicaprio agrees to donate it-factor to science',
#  'pork-laced bullets designed to send muslims straight to hell',
#  'study finds eating doctor after birth can provide essential nutrients to new mothers',
#  '5 things to know about megyn kelly',
#  'engineers are cold and dead inside, research shows',
#  'uber driver wants you to know that lots of mexicans live in this neighborhood',
#  'woman wears "won\'t be caught" t-shirt while robbing store',
#  'supporters aggravated bernie sanders didnâ\x80\x99t use dnc speech to get voters to act against their own self-interest',
#  'alligator becomes crime fighting beast as it catches car thief',
#  'martin shkreli bought sole wu-tang clan album, report says',
#  'woman allegedly beats man who farted in her face',
#  'obama currently being chased in background of secret service hearing',
#  'insecure infant worried he unworthy of animatronic toy rabbits love',
#  'nations couples hit rough spell',
#  "'storm area 51' facebook event draws only about 100 people, one arrested for public urination",
#  'mom announces plans to get out some of your old baby stuff and quietly stare at it',
#  'sick, elderly man screaming about foreigners stealing from him',
#  'biden getting an autobiography from the onion whether he wants it or not',
#  'vilnius mayor runs over illegally parked car in a tank',
#  'lawsuit: defective robot killed factory worker; human error to blame',
#  'wikipedia celebrates 750 years of american independence',
#  'is donald trump a racist, or is he following orders from a secret society?',
#  'drunk teen wearing flower pot used chainsaw to rob gas station',
#  'german siblings allowed to have sex by law',
#  "man requests 'trial by combat' with japanese swords to settle custody battle with ex-wife",
#  'delirious koala hasnt slept for 72 straight minutes',
#  'some maine republicans fret new state ballad is too hard on the confederacy',
#  "alaska man pleads guilty to assaulting woman and gets a 'pass'",
#  'megyn kelly out at nbc',
#  '30 hurt as traditional pillow fight at west point turns rough',
#  "father of boy in daring 'spider-man' rescue in paris was out playing pokemon go",
#  'clinton deploys very special forces to iraq',
#  'study finds rising sea levels result of expansive colonization effort by dolphins',
#  'man wishes there was some sort of sign he could put on his house to let visitors know he has gone fishing',
#  'this guy just used the indiana religious freedom law to open a church of cannabis',
#  'president obama gets to watch game of thrones season 4 before you do',
#  'eminem terrified as daughter begins dating man raised on his music',
#  'michael cohen reaches plea deal with prosecutors',
#  'the week in pictures – week of march 19, 2018',
#  'national weather service releases composite sketch of tornado it believes ravaged midwest',
#  'roger goodell: it nearly impossible for league to keep up with crimes regularly committed by nfl players',
#  'quirky restaurants bathroom had better fucking deliver',
#  'climate researchers warn only hope for humanity now lies in possibility they making all of this up',
#  'god cites moving in mysterious ways as motive in killing of 3,000 papua new guineans',
#  "florida man accused of attacking man who wouldn't let him pet dogs",
#  'fox anchor suing hasbro over toy rodent she says stole her likeness',
#  'wild-eyed jim harbaugh informs players they must kill their pregame meal',
#  'mother shot tv as kids watched primus video: police',
#  'capitan morgan sponsors initiative to let millennials to run for presidency.',
#  "alabama supreme court blocks digital ballot preservation requirement to verify the vote in tuesday's senate election",
#  'cleveland indians game delayed as slider goes into labor on field',
#  "father convicted in son's meningitis death a featured speaker at wellness expo",
#  'unsold google glass units to be donated to assholes in africa',
#  'clinton laughs off idea she politically savvy enough to launch revenge campaign on kavanaugh',
#  'christian pornographer refuses to film sex tape for gay couple',
#  'hawaii sends out missile alert by mistake.',
#  '19-year-old brit is paying her way through college by naming chinese babies',
#  "arizona lawmaker: immigration a 'threat' because 'there aren't enough white kids'",
#  'jeb bush keeps calling malia obama malala',
#  "maple syrup isn't just delicious, it could also cure alzheimer's disease",
#  'women voters cant help fawning over sexist gop',
#  'did you know that after hurricane ike in 2008, comcast customers were billed as much as $1000 for failing to return equipment destroyed in hurricane.',
#  "play-doh offers to replace 'dildo' playset tool after criticism",
#  'only 4 to 5 american-trained syrians fighting against the islamic state',
#  'democratic candidate blows fundraising lead on massive 15-story lawn sign',
#  'max clifford penis size evidence sees trial jury sent out for laughing',
#  'to save money, kentucky coal museum turns to solar panels',
#  'woman always really excited to be in whatever relationship status shes currently in',
#  'mysterious necrotic skin disease continues to eat away at babys face weeks after being kissed by ted cruz',
#  'man wastes no time masturbating while roommate gone for weekend',
#  'report: some dumb fuck out there probably wants his city to host olympics now',
#  "ufo enthusiasts naruto run through area 51 to 'see them aliens'",
#  'is sarah jessica parker a horse trotting around in a human body? you be the judge!',
#  'grizzly bear catches spawning michael phelps in jaws',
#  'residents of philadelphia, cleveland at least relieved they cant host another one of these fucking things for few decades',
#  'college student faces expulsion for trying to rent out dorm on airbnb',
#  'a bartender was fined for burping too loudly after eating a kebab',
#  'nintendo reveals smash bros. ultimate will allow characters to repeatedly punch self in face to freak out opponent',
#  'dennys introduces new 3,000-spider-egg omelet',
#  "russian man uses axe to chop off friend's genitals after losing penis-measuring contest",
#  'cincinnati teen who rapper 50 cent accused of being high, actually has a disability',
#  'man, 69, loses legal battle against temporal reality in effort to become 49',
#  'the pros and cons of a two-party system',
#  'gop promises americans will be able to keep current medical conditions if obamacare repealed',
#  'christian anti-masturbation’s mascot “fappy” arrested for public masturbation while swimming naked with the dolphins at sea world in san diego',
#  'report: just 2 more days and you can forget all of this, vanish into red dead redemption 2',
#  'man not even the hot kind',
#  'professor who is expert on corruption charged with laundering money',
#  'casual christian accepts christ as his lord but not his savior',
#  'engineers still unable to produce styrofoam cup without little center nub sticking out from bottom',
#  'alabama forced to release thousands of sex offenders after inmates deny charges',
#  'new study finds solving every single personal problem reduces anxiety',
#  'an interesting title',
#  'armless florida man charged with stabbing a tourist',
#  'man punches woman after asking for her number on cta',
#  'danish political candidate puts ad on pornhub',
#  'girl dubbed ‘queen of sweden’ after drawing ancient sword from lake',
#  'subway becomes even more crowded pit of humanity in 2015',
#  'fbi warns of american dream scam',
#  'the egyptian puppet accused of being a terrorist',
#  "ken starr on democrats' impeachment push: 'terrible mistake for our country'",
#  'ben carson primary party so quiet bartender knits blanket',
#  'claims of virgin births in u.s. near 1 per cent: study',
#  'florida man wearing "coke" shirt arrested for selling crack cocaine',
#  'youtube rushes to shut down school shooters account over copyright complaints',
#  'mizzou hunger striker jonathan butler reportedly from one-percent family worth millions',
#  'affordable housing only approved by community because of wall to border it',
#  'dead teenager remembered for great hand jobs',
#  'minecraft with rtx',
#  'fake doctor admits killing drag queen with butt implants',
#  'l.a. adds lanes for cyclists to recover from getting hit by cars',
#  'catches thieves just like flies: toronto spider-man snares shoplifter',
#  'most anticipated events of comic-con 2018',
#  'gop recommends americans set aside income from one of their jobs to pay for healthcare under new bill',
#  "police officers 'used helicopter camera to spy on people having sex'",
#  'israel serves japanese prime minister dessert in a shoe, causing offense',
#  'report: it crazy mlb still counts stats from segregated era',
#  'american dissatisfaction with everything is reaching historic levels',
#  "josh gordon says he 'definitely' does not have a drug problem",
#  '2012 after obama victory, shrieking white-hot sphere of pure rage early gop front-runner for 2016',
#  'ted cruz worried all the good countries to wall off taken by other candidates',
#  'chicago church robbed because of support of gop',
#  'steve kerr reminds warriors to seem sad demarcus cousins injured',
#  "florida court asked to decide if gay sex constitutes 'intercourse'",
#  'coworkers brought to place of unthinkable intimacy by team-building exercise',
#  "aclu lawyers blame 'christian right,' gop for orlando terrorist attack",
#  'portrait photographer surprised to discover his lens has apertures other than f/1.4',
#  'harper lee announces third novel, my excellent caretaker deserves my entire fortune',
#  'trump bestows medal of honor to john mccains tumor',
#  'man says fuck it, eats lunch at 10:58 a.m.',
#  'woman walked around with five-inch sex toy inside her for 10 years without realising',
#  'california elementary school students hurt after plane apparently dumps fuel over playground',
#  "milledgeville woman orders 'moana'-themed cake, gets marijuana design by mistake",
#  'mans wife dies of cancer just like in the movies',
#  'japan finally recognizes godzilla as a resident and tourism ambassador',
#  "four wendy's workers accused of dealing meth",
#  'campus tour guide reminds students at each stop they have to get in first',
#  'pussy-hat-wearing jeff flake spotted protesting outside senate ahead of voting yes for kavanaugh',
#  'morgan freeman: movie pirates have tiny, useless penises',
#  'new york attorney general claims assaults were just him role-playing as unaccountable male authority figure',
#  "pope francis warns 'bureaucracy is crushing europe'",
#  'vacationing uncle posts terse, emotionless facebook update from cruise ship',
#  'sunday alcohol sales campaign manager charged with drunken driving',
#  'honda civic refusing to start engine in solidarity with striking uber workers',
#  'bryan singer thinks he and kevin spacey could work together again',
#  "netflix film crews 'banned from looking at each other for longer than five seconds' in #metoo crackdown",
#  'john bolton insists iran likely harboring dangerous terrorist osama bin laden',
#  'body positivity advocate caught in illicit tryst with conventionally attractive lover',
#  'nostalgic hope hicks barely recognizes young woman on white house id badge',
#  '\u200bchina, russia &amp; north korea to create international tourist zone',
#  'family has strict no smartphone rule while eating dinner in front of tv',
#  'buddhist temple in japan puts faith in robot priest',
#  '45-year-old loser moves in with parents',
#  'judge restricts roger stones travel between fox news, infowars studios while released on bond',
#  'zimbabwe president robert mugabe locks up gay couple, promised to release them when one of them gets pregnant',
#  'scientology tv network sets launch',
#  'marty’s chilly message to daredevils: stop jumping out of windows!',
#  'melanias heart sinks after realizing husband uses pet name horseface for every woman he fucks',
#  'mike pence horrified by d.c. cherry trees flagrantly displaying reproductive organs',
#  'students sue to open yale fraternities to women',
#  'bill gates pledges $12 million for universal flu vaccine',
#  'did russians leak sherlock? claims kremlin leaked final sherlock episode online as part of plot against bbc',
#  'nobody held accountable for crimes manning revealed, except himself',
#  "zuma wanted charges dropped because corruption is a 'western thing'",
#  'report: mueller investigation nearly done with first day of trump campaign',
#  'study finds flushing toilets wastes billions of gallons of piss and shit annually',
#  'scientists discover adorable new species hiding in the junk drawer',
#  'how confirmation hearings work',
#  'newborn has fathers asshole',
#  'living near walmart means you are probably fat, study sort of says',
#  'holocaust survivors recall exact day holocaust started right out of the blue',
#  "whiffyleaks! julian assange's 'poor hygiene played a role in ecuador's bid to end his five-year standoff in its embassy after staff complained he wasn't washing properly'",
#  "esquire editor explains women are 'objects'",
#  'area ladder never thought it would end up a bookcase',
#  'ammo box falls from military chopper, crashes into texas school',
#  'us willing to hold talks with edward snowden, but only if he pleads guilty first',
#  'ink-splattered trump boys counter media bias by hand-printing own newspaper in white house basement',
#  'florida woman arrested for allegedly riding manatee.',
#  'margate man wants to show penis to beat murder rap',
#  'humiliated man discovers embroidery on his jean pockets',
#  "russian city councilman's wife who twerked in front of ambulances on the moscow beltway is fined 300 bucks",
#  'barron trump sprints off convention stage in tears after missing note during clarinet solo performance',
#  '10 giant cocks nsfw',
#  'obama returns from paris climate talks with couple energy-efficient light bulbs',
#  'the church of the flying spaghetti monster can now perform marriages legally in new zealand.',
#  'harrison ford begs agents to just let him die now',
#  'china threatens to arm hawaii separatists who want kingdom',
#  "man with 'chronic runny nose' told his brain was leaking",
#  'australia looks set to start bombing syria as liberals warn against too much refugee compassion',
#  'russian shot in quarrel over kant’s philosophy',
#  'completely sober employee still embarrassing self at company party',
#  'brad pitt sidelined 6 to 8 weeks with red carpet toe',
#  'man who advocated for caning to adulterers gets caned',
#  'vermont man takes revenge on town board with a 700-pound statue of a middle finger',
#  'trump selects longtime personal plane to head faa',
#  'ennis priest gives burglar a lift after finding him in wardrobe',
#  'trump signs bibles during disaster tour of alabama',
#  'supreme court legalizes gay marriage',
#  'social media linked to increased loneliness',
#  'proposed texas bill to fine unregulated masturbation moves ahead',
#  'man receives sex act while blacked out, gets accused of sexual assault',
#  'secretary of treasury announces plan to remove gross penny from circulation',
#  'mit aims to build fusion power plant within 15 years',
#  'shitty region of country figures it might as well give producing wine a shot',
#  'top 10 tv moments of 2014',
#  'woman claims the devil chased her into underground pipe in front of pearl library',
#  'emoji licence plates launch in australia',
#  'police arrest man for allegedly having sex with dying beaver while high on methamphetamine',
#  'oops: new sun-reflecting london skyscraper melts cars',
#  'nhl warns hockey fans that banging on glass scares players',
#  "nasa cancels first all-female spacewalk because it didn't have two fitting spacesuits",
#  'trail blazers fans play the worst tic-tac-toe game of all time',
#  'disappointing prince vaults found to contain 37,000 hours of billy joel covers',
#  'comey warns democrats that having leftist politics gets you on the fbi watchlist',
#  'bin laden vineyard falling into disrepair',
#  'chinese jobseekers face "zodiac discrimination". you virgo? no job for you.',
#  'man accused of abandoning pet fish has animal cruelty charges dropped',
#  'oklahoma police give lost donkey squishy a ride in patrol car',
#  'man’s wife, girlfriend place dueling obituaries in same new jersey newspaper',
#  '5 things to know about james mattis',
#  'head of group opposing iran accord quits post, saying he backs deal',
#  'epa says scott pruitt flies first class because angry people yell at him too much',
#  'pope francis working out at vatican gym wearing sex abuse summit 2019 t-shirt',
#  'til china killed off two ai chatbots after they start criticising communism and praising the us.',
#  'top newsmakers of 2016',
#  'coed rec softball team having trouble finding enough hyper-competitive men to ruin experience',
#  "sex partner must say 'yes' every 10 minutes or it's rape, 10th graders taught in california",
#  'obama spends afternoon in garage restoring classic drone',
#  'every bar patron watching world cup has different, incorrect definition of offside rule',
#  'census adds question asking participants to identify any unpatriotic neighbor',
#  'nike makes colin kaepernick face of new ad campaign',
#  'frat nutritionists dare americans to swallow more live goldfish',
#  'woman finds semi-automatic rifle inside goodwill baby bouncer box',
#  'experts say earliest warning signs of mental health issues usually crossing eyes while dribbling finger on lips, saying cuckoo, cuckoo',
#  'artist immortalizes marx as garden gnome',
#  "driver 'blows up' car with 'excessive' use of air freshener",
#  'affiliate programe - ucw88',
#  'study finds mediterranean diet adds years to your life, but only by taking them away from others',
#  '26-year-old to see every asshole he ever went to high school with on night before thanksgiving',
#  'meth lab allegedly found at former drug rehabilitation centre',
#  'preacher forces son to eat an entire bible after he converts to islam',
#  'experts confirm rainforest ecosystem destroyed to make room for social server farm wasnt that impressive to begin with',
#  'patrick stewart reveals he spent most of his life not realizing he’s uncircumcised.',
#  'halloween edition: pied pipers dressed as clowns lure kids into dark woods',
#  "church 'regret' as trainees hold service in gay slang",
#  'pornography-desensitized populace demands new orifice to look at',
#  'tucker carlson insists every white supremacist in stadium but tickets to tuckercon wont last',
#  'kanye west named new face of yeezy',
#  'video: puddle of mudd frontman accuses audience member of stealing his house, walks off stage',
#  'report: just go ahead and tell yourself bribery is the only reason you didnt get into columbia',
#  "british security bosses' g20 safe sex warning: don't sleep with china's spies",
#  'parrot was ‘beaking off’; man’s shouting match with bird mistaken for domestic assault',
#  'isis stops using iphone after apple ceo announces that he is gay',
#  'iran-contra’s oliver north slams $400 million transfer: obama gives iranians ‘whatever they want’',
#  'white americans are biggest terror threat in u.s.: study',
#  'woman stashes loaded gun in her vagina',
#  'ten years later, cheney haunted by people he didnt manage to kill in iraq war',
#  "missouri governor signs 'revenge porn' bill hours before leaving office over revenge porn allegations",
#  'hardened white blood cell no longer hesitates to kill viruses',
#  'florida mayor resigns after arrest for allegedly shooting at police officers.',
#  "'most dangerous bird in the world' that killed its elderly owner being put up for auction",
#  'china bans all types of fentanyl',
#  'queensland election: drive-through polling booths open at cleveland, sunshine coast',
#  'archaeologists uncover greek amphitheater where first prick saved seats',
#  'man walks on fucking moon',
#  'prominent figure of #metoo paid for the silence of a 17 year-old child actor she sexually assaulted',
#  'jon gruden rips up list of top prospects and drafts from the heart',
#  "pharrell sent trump cease-and-desist letter for playing 'happy' at event after synagogue shooting",
#  'nhs bosses apologise for calling single mothers a burden',
#  'hipster toad has weaponised moustache',
#  'pack of dachshunds kill woman in oklahoma',
#  'trump claims he tried to warn public about epstein by praising him as a terrific guy',
#  "7 apple watch prototypes that didn’t make the final cut and we can't figure out why",
#  "nyc mayor: police stop minorities 'too little'",
#  'polar vortex splits into u.s.-chilling rings',
#  'hiawatha man now charged with murder, accused of killing mom with an apple.',
#  'indignant bill belichick evades question by cutting off reporters tongue',
#  'steak made from human poop passes taste test',
#  'north korea successfully detonates nuclear scientist',
#  'swiss tv station replaces cameras with iphones and selfie sticks',
#  'study finds sexism rampant in nature',
#  'mitch mcconnell has hands, vocal cords removed to prevent self from holding hearing on scalia replacement',
#  'experts warn beef could act as gateway meat to human flesh',
#  'ice agents feeling a little hurt that trump doesnt think theyre doing enough to terrorize hispanics',
#  'a judge tried to fine a man $1 for every time he groped an underaged girl',
#  'man actually thought injecting semen into his arm would cure his back pain',
#  'sarah huckabee sanders denies doctoring footage showing jim acosta in clown makeup blowing up gotham hospital',
#  'trump relieved to learn both teams in stanley cup finals overwhelmingly white',
#  'new parents disgusted to learn they had type of baby that shits',
#  'this is a russian bear playing hockey',
#  'woman sues background check site after husband uses site to catch her cheating',
#  'poll: majority of evangelicals would support satan if he ran as republican candidate',
#  'alberta mla says marijuana legalization could lead to communist revolution',
#  'dads eyes well up at sight of perfectly packed cooler',
#  'no matter what happens tomorrow, at least i had fun',
#  '450 illegal tamales from mexico seized at lax and &amp;apos;incinerated&amp;apos; not steamed',
#  'doctor: man accused of killing wife was delirious from pot',
#  'wealthy father nervously waits for response after sending donations to son\x80\x99s top college choices',
#  'cottonelle adds blue strip to toilet paper but keeps what it does a secret',
#  'chinese city designates lanes for walking while texting',
#  "frankie muniz's house flooded by cat.",
#  'florida babysitter ties baby to ceiling fan for 26 hours.',
#  'bored iowa town trying to convince kirsten gillibrand it local tradition to eat live tarantula',
#  'oliver north named new president of the nra',
#  'join email list box pre-checked like sneaky, conniving fucker it is',
#  '3m introduces new line of protective foam eye plugs',
#  'pressure mounting for humans to step down as head of failing global ecosystem',
#  'pope francis holds sex abuse summit',
#  "'women must earn less than men,' polish politician says",
#  '8 key google analytics reports for seo',
#  'reddit is down so expect a population boom in about 9 months',
#  'college graduate first person in family to waste $160,000',
#  'nbcu readying streaming service that pays viewers to watch it',
#  'pat robertson: comfort grieving mom by saying god stopped her dead baby from becoming next hitler',
#  'indigenous elder says inukshuk art at toronto airport warns of death, suicide',
#  'david attenborough says collapse of civilization on horizon',
#  'furious meghan markle cant believe harry hasnt told family shes black yet',
#  'chess grandmaster tired of people comparing every life situation to chess match',
#  'london takes just one week to breach annual air pollution limits',
#  'this bitter couple tells us the secret to a 3-year, 5-month, and 2-week marriage',
#  'highly qualified second grade teacher...',
#  'report: publicly humiliating unpopular student still leading cause of telekinetic violence in u.s. high schools',
#  'saved from a santería priest, rescue rooster terrorizes a miami neighborhood',
#  'students seeking sugar daddies for tuition, rent :: wral.com',
#  'women from canada gets sentenced after causing death of two people by leaving her car on the highway to help ducklings',
#  'man assumed being heartless, egotistical maniac would have made him richer by now',
#  'vindman says ukraine transcript left out lengthy sections of trump bragging about time he was in pizza hut commercial',
#  'what is the alt-right?',
#  'canada prison escapees caught by police in escape room',
#  'ice sends agents home with sacks of flour to practice what it like detaining real baby',
#  "delhi man beaten up after making 'don't urinate in public' request, dies",
#  'man approaches box of powdered doughnuts like snake discovering unguarded clutch of bird eggs',
#  'parents clinging to lone religious element of daughters wedding ceremony',
#  'death row inmate dies of natural causes 3 days into execution',
#  'report: majority of statements now prefaced by phrase in light of recent events',
#  'report: west virginia feeling pretty smug right about now',
#  "irish soccer team fakes player's death to get out of game because forfeiting is boring",
#  'tom brady unfazed by completely detached right hand',
#  'blagojevich daughter: ‘spineless’ obama has ‘broken my heart’',
#  'city of baltimore targeting young professionals with new you get used to it campaign',
#  'police: florida man cited for eating pancakes in the street',
#  'out of spite: the governor of nebraska’s threat to execute prisoners',
#  'man plugs his ears and yells at judge during court hearing',
#  'gop lawmakers watch silently as trump strangles each of their loved ones in turn',
#  'wwe: illegal mexican wrestlers taking smackdowns american wrestlers dont want',
#  'world wildlife fund apologizes after years of working with well-known whale pedophile',
#  'cat owners might be more into bondage and bdsm than everyone else',
#  'a protester pelted martin shkreli with dog poop',
#  'equifax impressed by hackers ability to ruin peoples finances more efficiently than company can',
#  'trump to press: i consider you part of the democratic party',
#  "a restaurant in london's covent garden is serving a new range of ice cream, made with breast milk.",
#  "chuck lorre apologized for 'two and a half men'",
#  "woman claims 'urinating' toy sexually assaulted her at hibachi restaurant",
#  'estée lauder expedition stumbles upon frozen remains of previous party sent to retrieve rare moisturizing herb in the himalayas',
#  'jerry jones offers to pay players fines for domestic violence',
#  'malaysia hires witch doctor to find missing plane',
#  'raccoons bust into toronto woman’s home, stare her down while defiantly eating her bread',
#  'police: man accidentally confesses to rape during police job interview',
#  "'i felt like james bond': boy, 13, enlists taxi in chase across city to find iphone he left on bus",
#  'ben and jerrys releases donald trump resistance-inspired flavor',
#  'maria butina pleads guilty to russian scheme to influence conservatives',
#  'cool guy from middle school still sporting phat pair of jncos',
#  'man utd may alter director of football plan after success of transfer window',
#  'apartment kind where weed just left out on coffee table',
#  'eagle_warrior_1776 horrified to discover its entire life a sham created by russians to tilt u.s. election',
#  'white house insists it wont dictate the manner in which kavanaugh exonerated',
#  'chinese teen stows away in a380 to make fortune in dubai',
#  'pros and cons of talking politics at work',
#  'petition demands adele admit she’s successful only because she’s white, and insists she give away her money',
#  '12 top-paying jobs in the u.s.',
#  'area man much happier, more relaxed since joining cult',
#  'intrepid middle-class parents embark on daring search for mythical perfect school district',
#  'shell corp is sponsoring an article titled "how green are those solar panels, really?" on national geographic\'s news website.',
#  'gm, ford, and others want to make working on your own car illegal',
#  'people in open-concept homes are realizing the walls were there for a reason - the boston globe',
#  'man dead after baltimore port-a-potty fire',
#  'blogger hopes her 6-year-old son is not to blame for low likes.',
#  'woman charged with killing husband after fight over burned casserole',
#  'remington debuts new split barrel murder-suicide shotgun.',
#  'overweight 6-year-old vows to change lifestyle after second heart attack',
#  'pope francis finds self in hell after taking wrong turn in vatican catacombs',
#  'russians admire chocolate putin statue',
#  "wu-tang clan's once upon a time in shaolin bought by pharmaceuticals ceo martin shkreli",
#  'court oks barring high iqs for cops',
#  'macys concludes thanksgiving day parade with traditional procession of santas coffin',
#  'hpv vaccine linked to dramatic drop in cervical disease',
#  'myth vs. fact: sunscreen',
#  'robert de niro stunned to learn of man who can quote goodfellas',
#  'cousin really going all-in on retweeting porn stars',
#  'chess grandmaster, 20, dies in parkour balcony fall',
#  'state of connecticut is forcing a teenage girl to undergo chemotherapy',
#  'trump furiously searching raytheon catalog for gift after realizing he promised china and ukraine same javelin missile',
#  'emirates literally just made an entire commercial trolling united airlines',
#  'report: 80% of all traffic accidents caused by drivers gawking at shirtless hunks',
#  'university officer may be sacked after racist tweet.',
#  'after satanists planned to give away coloring books, florida school board halts religious distributions entirely',
#  '92% of area womans holiday recipes involve pulverizing bag of oreos',
#  'crusted ring around nyquil bottle top coming along nicely',
#  'man charged for faking disability to get diaper changed',
#  'russia planning aid convoy of christmas trees for eastern ukraine',
#  'woman reportedly returns dead christmas tree to costco, gets full refund',
#  'gluten-free pancake mix just a bag of sand',
#  'your horoscopes — week of september 18, 2018',
#  'fox news says kendrick lamar “has done more damage to young african-americans than racism”',
#  'will google sue sue googe?',
#  'courses in harry potter and "ethical hacking" offered by universities',
#  'hungover coworker a little too functional morning after holiday party not to be alcoholic',
#  'sudanese 14-year-old has midlife crisis',
#  'mexican police force armed with slingshots after guns confiscated',
#  'car rolls up to stoplight blasting google maps directions',
#  'chinese officials vow to fix nations crumbling reeducation system',
#  'china sends vines into space in quest for perfect wine',
#  'trump climbed the steps of air force one with a thin piece of paper stuck to his shoe',
#  'what do you get for the man who already has the complete fleetwood mac discography?',
#  'man fell from fourth floor in armenia, saved by virgin mary',
#  'trump covered in own shit after furloughed white house staff fail to bathe president',
#  'report: half of all americans probably should have thought of that before they opened their mouth',
#  'high school drama teacher already has pretty good idea who hell pick for fall girlfriend',
#  'utah school realizes it shouldn’t ask students to make terrorist propaganda posters',
#  "ben carson: others can't sell shirts, stickers supporting me",
#  "mcdonald's quarter pounder suit: diners charged for unwanted cheese",
#  'horrified investigators find unresponsive legislative body in capitol building',
#  'i just wish nfl players could find a way to protest without starting a national dialogue',
#  "lori loughlin hires prison coach to learn martial arts: 'worst advice' thus far, expert says",
#  'slide-whistleblower complaint reveals trumps pants around ankles',
#  'how devos plans to change the department of education',
#  'squirrels in cardiff are really fat because of the mild winter weather',
#  "mom abandons eight year old son at hospital with a note saying he was 'rude' and 'ungovernable'",
#  'four homeless people dead in what girlfriend refers to as “cuddle weather”',
#  'man solemnly realizes there always going to be other apartment hunters out there smarter, faster, more cunning',
#  'two saints season-ticket holders are reportedly suing nfl commissioner roger goodell and the league for a range of damages — including mental anguish, emotional trauma and "loss of enjoyment of life."',
#  'kidnapped teen freed, though freedom is its own kind of prison, is it not?',
#  'overwhelmed nsa surprised to discover its own surveillance "goldmine" on venezuela\'s oil executives',
#  'new ted cruz attack ad declares beto orourke too good for texas',
#  'sex worker on $7000 a week ‘needed’ drugs, says judge',
#  'chicken and biscuits bank robber gets 2-4 years',
#  'suicide rates falling worldwide',
#  'grandsons jigsaw puzzle strategy fucking pathetic',
#  'gop hopefuls speak at anti-gay conference',
#  'your horoscopes — week of august 7, 2018',
#  'the mods are gone so lets party. shhhh',
#  'boy cautioned by police for playing dungeons &amp; dragons',
#  'inconsolable jeff sessions tries to commit suicide by smoking joint',
#  'woman claims she underwent 50 plastic surgeries to look like angelina jolie',
#  'tom brady feeling guilty after gorging self on full order of kansas-city-style tap water',
#  'the average college freshman reads at 7th grade level',
#  'heroes of the storm player faces five years in jail for threatening blizzard staff with ak-47',
#  'fresh beef coming to mcdonalds',
#  'man who changed his name to sexy vegan arrested for sexually assaulting his pitbull',
#  'miami heat confident they have the right officiating to triumph over pacers',
#  'amsterdam police perform a special rescue',
#  'biden campaign concerned after candidate gives unsolicited back rub to coat rack',
#  'is andrew luck fully recovered from his quadruple-amputation surgery?',
#  'satanists rally for gov. rick scott',
#  "indonesia drugs: crocodiles 'to guard death row prisons'",
#  "hangovers don't delay the next drink, study finds",
#  "cop fired after acting out scene from 'training day'",
#  'boyfriend plans magical evening down to first detail',
#  'heaven slides to sixth place in annual quality of afterlife rankings',
#  'toys r us prepares to liquidate business',
#  'i married myself and it was truly empowering',
#  'study finds 70% of bingo winners end up prizeless within 5 years',
#  'noam chomsky announces las vegas residency',
#  '180 trillion leisure hours lost to work last year',
#  'she went to college for a job, and found a husband, too',
#  'a uae woman filed for divorce after husband forgot to pick her burger for dinner',
#  "the white house website cited a parody article as support for trump's budget",
#  'maine gov. paul lepage pardons dog on death row, now being investigated for dog pardoning powers',
#  'illinois gun shop raffles ar-15 to raise money for orlando victims',
#  'florida senate approves bill allowing armed teachers',
#  'should companies discontinue unpaid intern fights?',
#  'the pros and cons of militarizing the police',
#  'washington, d.c., is counting all its cats. it will take 3 years and $1.5 million',
#  'burned armpit hair led to car crash',
#  'ex-lawmaker who fought child porn bragged about molestation: ’12 is about as old as i can handle’',
#  'civil union for same-sex couples, ugly, rich people',
#  'man on tv dating show reveals killing first wife, lover',
#  'aggressive flagellate just going around whipping other single-celled organisms',
#  'woman not going to let husband of 60 years drag her into death at same time',
#  'dunkin donuts unveils new seasonal rotting jack-o-lantern latte for end of fall',
#  'woman fined for being too short to get rubbish into her bin',
#  'stolen bus takes students to finals',
#  'netanyahu assures critics he still has utmost respect for u.s. money',
#  'обзор ford fiesta v 1.6 2007 разгон до сотни за 3.6 сек.',
#  'pilot tells passengers hes about to try something',
#  'jared kushner spends fourth consecutive day silently ensnared in decorative white house spider webs',
#  'man accused of sexual assault after brushing past a woman in a busy train station. after a year long ordeal a jury acquits him within minutes.',
#  'trump, kim meet in hanoi summit',
#  'thieves steal herd of pregnant goats',
#  'its real easy, declares it guy about to speak incoherently for next 30 seconds',
#  '2016 fish of the year is…this fish',
#  'piggies written in blood on clouds only clue in shocking murder of six angels',
#  'woman found on mars',
#  'idea of doing nothing until next mass shooting quickly gaining traction in congress',
#  'walmart thieves steal barbie car, using fake heart attack as a diversion',
#  'donald trump named time person of the year',
#  "jeremy hunt tells chinese hosts his wife is japanese - when she's actually from china",
#  'woman sells positive pregnancy tests on craigslist to pay her way through school',
#  'trump’s pick to lead the epa is suing the epa over climate change',
#  'fan who caught homerun ball insists it cleared the wall',
#  'classically trained actor can talk on cue',
#  'thats it? what the heck was that? says dad in scorched-earth review of movie you suggested family watch together',
#  'usa gymnastics confident they have plan in place for next time doctor sexually assaults 150 children',
#  'fact checks: president trumps press conference',
#  'death star petition gets white house rebuff',
#  'cyberbullying alert: gamers are ganging up to harass this defenseless chinese communist party leader',
#  'suspect hiding from police passes gas so loudly that it gives up their hiding spot',
#  'sinclair’s plan to take over local news just hit an unexpected roadblock: trump’s fcc.',
#  'family spends relaxing weekend destroying outdoors',
#  'throttling of websites and online services might help customers, fcc says',
#  'father of 22 unfazed by displacement, only interested in getting fourth wife',
#  "ukraine: poroshenko holds one-man 'debate' before run-off",
#  'survey finds many gamers never finished red dead redemption 2',
#  'audubon zoo gorilla throws block of wood at pregnant woman',
#  'lottery ticket holder has already spent $900 million in anticipation of winning big prize',
#  'struggling media company almost desperate enough to hire someone qualified for job',
#  'starbucks says it will ban people from viewing porn in its stores by 2019',
#  'en passant, whispers mueller as he knocks another pawn off chessboard in shadowy, dimly lit office',
#  'man wins $273m jackpot, gets call from ex-wife',
#  'mans truck stolen while he was robbing a store across the street.',
#  'donald trump stares forlornly at tiny, aged penis in mirror before putting on clothes, beginning day',
#  'creepy older brand clearly targeting female 18-to-24-year-olds',
#  'good news kept from parents out of fear of proving them right',
#  'what is milk? dairy and almond industries clash over four-letter word',
#  'star wars fan spends $300,000 on botox to look like jabba the hutt',
#  'european leaders: we stand together to say loud and clear: we are scared as fuck and dont know what to do',
#  'jeb bushs children vehemently deny having ever loved father',
#  'millennials can’t buy homes because they’re wasting money on avocado toast, helpful millionaire says.',
#  'wells fargo computer glitch accidentally forecloses on all 5,700 branches',
#  'cbs reveals big bang theory season 12 will explore why sheldon keeps job after sexually harassing 6 research assistants',
#  'marco rubio still rock-hard days after being publicly humiliated on national stage',
#  'pornhub expands parental controls for user accounts',
#  'paul ryan confident american people will warm up to tax plan once they realize life a cruel and meaningless farce',
#  'boston free speech rally organizer sues marty walsh for slander x-post r/boston',
#  'fan bravely ventures to other side of stadium in search of better food options',
#  'download 802 11b/g wlan driver 0 7 1001',
#  'pr mogul roxy jacenko exposes female poo jogger outside sydney office',
#  'report: massive hypocrisy just flat-out gets the job done',
#  '5 things to know about julián castro',
#  'new facebook notifications alert users when they not currently looking at facebook',
#  'north korea is suffering a complete internet outage',
#  'cancer is the best way to die because it allows people time to say goodbye claims leading doctor as he calls for an end to spending billions searching for a cure',
#  'human slave from future remembers when cyber monday was about celebrating savings, not robot uprising',
#  'mitch mcconnell dodges reporters question by quickly stepping into empty elevator shaft',
#  'aging mount st. helens starting to think erupting days are behind it',
#  'company commits to hiring more bengal tigers in effort to improve office biodiversity',
#  'judge denies manafort request to wear suit in court',
#  'spring breakers freaked out as fishermen drag sharks onto florida beach',
#  'quick scan of room confirms area man once again sweatiest person present',
#  'tips for handling social anxieties',
#  "dea chief's daughter arrested for selling cocaine, marijuana, ecstasy and lsd; released immediately on bail",
#  'phoenix couple accused of forcing day laborer to have sex at gunpoint',
#  'pastafarian colander pic strains legality for dutch license',
#  'amy schumer rubs deodorant between thighs before red carpets',
#  "russian parliament considers condemning 'annexation' of east germany in 1989.",
#  'cat dead set on finding way into mirror',
#  'indonesia plans crocodile-guarded prison island for drug convicts',
#  'cdc horrified after discovering existence of thousands of public pools',
#  'avocado thieves stealing thousands of dollars of fruit in midnight raids - before selling them on to millennials',
#  'calgary airport apologizes for turning disabled parking spaces into lexus-only spots',
#  'report: this movie old enough that they might have actually hurt dog',
#  'its not an easy thing to admit when youre wrong, and thats why i wont do it',
#  "new zealand tells australia: stop 'copying' our flag",
#  'argentinian officers fired after claiming mice ate half a ton of missing marijuana',
#  'nasa plans first all-female spacewalk',
#  'mueller ready to deliver major parts of findings after midterms',
#  'samsung smart tv owner learning about majority of features from leaked cia documents',
#  'james comey quickly reopens clinton email investigation for few more minutes',
#  'how hollywood can address the gender gap',
#  '"if i could be just completely honest for a second, i believe exactly what you believe" says hillary clinton',
#  'cuban immigrant cant believe he risked life coming to america to play for aa birmingham barons',
#  'mayor says town seal depicting white man strangling native american is a "friendly wrestling match"',
#  'incredibles 2 forced to take out grisly cannibalism scene in order to secure pg rating',
#  'antonio brown buys pittsburgh billboard to thank antonio brown for putting up with city',
#  "horrified teen thinks she's kylie jenner after having wisdom teeth removed",
#  'man on verge of self-realization instead turns to god',
#  'so what did i miss? asks michael flynn tilting large flower on lapel towards trump',
#  'u.s. army is concerned by cyborg soldiers due to terminator movies',
#  'there is only one person registered as a "rectal teaching assistant" in the uk, traveling the country offering his anus to be examined by trainee doctors. he has since lost his job to a robot anus.',
#  'semen syringe squirter arrested after reign of terror at us malls',
#  "man jailed for sexually assaulting four-year-old girl said he 'thought she was 18'",
#  'moon now overrun with cane toads after species accidentally introduced into environment during apollo 17 mission',
#  'red sox team doctor unclear whether he supposed to join fight or not',
#  'yosemite expands lodging accommodations with new log cabin high-rises',
#  'skip bayless rips shannon sharpes heart from body during debate on cowboys o-line',
#  'drunk man sends injured baby bird to wildlife rescue center in an uber',
#  'sausage-wielding gang attacks vegan cafe',
#  'whale wont shut up about time it was beached',
#  'you thought you could get rid of me? says cassini probe emerging from shadows to confront petrified nasa administrator',
#  'the yankees have the worst beer list in baseball',
#  'whatever crushed squirrel must have been pretty heavy',
#  'trump considering releasing detainees in sanctuary cities',
#  'older prostitute explains to younger prostitute who richard belzer is, what he expects',
#  'ice opens interdimensional detention center to indefinitely imprison immigrants across infinite number of multiverses',
#  'fbi raid on trumps lawyer sought files related to access hollywood tape',
#  "her divorce is not final until she proves she is not the father of her wife's twins",
#  'trump delivers touching tribute to fallen heroes of wwe',
#  'snp apology call after north sea oil discovery',
#  'snooze button time traveler sets coordinates for 5 minutes into the future',
#  'trump boys leave $5 bill, candy bar under propped-up laundry basket in effort to catch op-ed writer',
#  'one dead after poop transplant gone wrong, fda warns',
#  'shop shut down after sticking fake googly eyes on fish to make them appear fresh',
#  'even porn sites are joining in hong kong’s fight against a hated extradition law',
#  'papa johns comes under fire for cruel treatment of the bulbous, deformed creatures that lactate pizza sauce',
#  'experts: ebola vaccine at least 50 white people away',
#  'goat breaks free, goes on starbucks run in california',
#  "gibraltar accuses eu of behaving like a 'cuckolded husband who is taking it out on the children'",
#  'mike gravel cant believe his polling numbers neck-and-neck with fucking nobody like wayne messam',
#  'outside the red hen, fire and ire on social media come to life',
#  'uk pre-teen rapes younger sister to recreate grand theft auto sex scenes',
#  'the most beautiful girl in the world 2018 and 2019 compared',
#  'woman confident she has the safety net it takes to achieve dreams',
#  'grossed-out anti-abortion activist has change of heart after seeing picture of fetus for first time',
#  'woman longs for day when first female president can have tell-all book written about disgusting vagina',
#  'u.s. falls in annual global corruption rankings',
#  'half-dressed man frantically scrambles out of home after hearing toyotathon deals wont last long',
#  'frustrated employee no longer even trying to hide gre study books',
#  'cats deadlier than anyone realized.',
#  'india sentences man-eating lion to life — in the zoo',
#  'report: 99% of employees would use boss as human shield in event of workplace attack',
#  'man wearing jewmerica t-shirt never dreamed hed see this day',
#  'police at texas fest played rock-paper-scissors with underage drinker',
#  'humanity hoping it only has to put up with few more millennia of this shit',
#  'selfie-defense courses teach russians to use selfie sticks as weapons',
#  'poll finds 100% of americans blame shutdown entirely on colorado representative scott tipton',
# ...
#  'governor demands to know which star on american flag is iowas',
#  'craigburn primary school’s ‘wear a dress’ fundraiser blasted by senator cory bernardi — but his comments send donations skyrocketing',
#  'it says here on your résumé, mr. zimmerman, that you shot a boy?',
#  'devout mormon appointed to the utah department of alcoholic beverage control, replacing another devout mormon',
#  'group of friends engage in passionate, incoherent discussion about current events',
#  'police: upset with neighbors, st. johns woman bulldozes their mobile home',
#  'violence and porn increase after the superbowl',
#  'california proposes a plan to tax text messages',
#  'wife leaves husband of 22 years because he voted for donald trump',
#  'white supremacist living fulfilling racist life since getting kicked offline',
#  'rust belt town protests construction of new truck stop that would obstruct views of state penitentiary',
#  "the hard data on ufo sightings: it's mostly drunk people in the west",
#  'al qaeda’s new front: jihadi rap',
#  'hollywood sign vandalized to read "hollyweed"',
#  "plastic tunnel at a supermarket has become town's highest rated tripadvisor attraction",
#  "putin draws picture of cat's behind during school visit",
#  'college residence office gets kick out of pairing up few roommates who will fucking hate each other',
#  'heart attack grill spokesman dies from heart attack',
#  'breaking bird: crow reveals secret perth meth stash',
#  'flying bear kills two canadians in freak accident',
#  'wwii bomb scare leads german police to something else: a heavy zucchini',
#  'american exchange students in italy start fire by cooking pasta without water',
#  'halloween unfortunately not only night of year area man drunk in firefighter uniform',
#  'data: chicago cubs fans are no. 1 at urinating in public',
#  'nra says mass shootings just the unfortunate price of protecting peoples freedom to commit mass shootings',
#  'elon musk to open first high-speed test tunnel on december 10',
#  'this guy is pissed about all the mysterious free pizza he keeps getting',
#  "trump doesn't think he's 'ever even heard of a category 5' hurricane. four such storms hit the us since he took office",
#  'cnn investigating reports of wolf blitzers highly proper sexual conduct',
#  'andrew cuomo meets with admitted former crack dealer jay-z to discuss police policy',
#  'sepp blatter tweets about ethics in football',
#  'ugly christmas sweater trend spreads nationwide',
#  'jakob dylan still not convinced father a better songwriter',
#  '5 things to know about elizabeth warren',
#  'metropolitan museum acquires another vase',
#  'cowboy lassos would-be thief outside walmart',
#  'george bush accidently votes for obama',
#  'update:  has halted production on our travel tips video narrated by jeremy piven',
#  'dog tuxedo bought with arkansas county credit card, document says',
#  'candidate profile: rick perry',
#  'man insists facebook friend actually reads why palestinians are sub-human article before commenting on it',
#  'california camp fire fully contained',
#  'can you still be sexy after 50?',
#  'sony reveals playstation 5 will feature fully functioning breakfast sandwich maker',
#  '\u200btrump vows to stop eating oreos, citing move to mexico',
#  'an aborted fetus in alabama just got the right to sue the abortion clinic',
#  'ksp: homeowner unknowingly shoots police officer',
#  '"we’re america, bitch:" white house official defines trump doctrine',
#  'matthew berry admits he just drafts fantasy players whose names he recognizes',
#  'putin inspires new ‘attractive, matter-of-fact’ fragrance now available in moscow',
#  '27-year-old lies about every single aspect of his life to keep parents from worrying',
#  'paul giamatti cuts back on acting to focus on signature line of shapeless khakis, rumpled polos',
#  'postal service releases stamp with anus on it to see if anyone cares whats on stamps anymore',
#  'idaho woman blames car crash on deer-chasing bigfoot',
#  'blind people in iowa can get gun permits....',
#  'cop just in it for the frisking',
#  'area woman will have to be way more fucking pregnant than that if she wants to be offered subway seat',
#  'cryptocurrency firm losses $145 million after ceo dies with only password',
#  "florida woman says cop tried to apologize with 'sorry i tased you' cake",
#  'trump raises concern over members of urban communities voting more than zero times',
#  'facebook finds that not all users want to review their year',
#  'embarrassed alexandria ocasio-cortez can only afford american flag pin with 19 stars',
#  'pope francis popularity down among catholics',
#  'japan pledges to halt production of weirdo porn that makes people puke',
#  'purina debuts new slovenly feast for nasty-ass shelter cats',
#  'giuliani: lets just start everything over',
#  'jon stewart to host wwe summerslam 2015',
#  'how companies are going green',
#  'family out $5k after buying ice cream on vacation',
#  'high school students now prefer marijuana to cigarettes',
#  'this ukrainian man changed his name to iphone 7 to get one for free',
#  'anytime trump wants to take that iq test, mensa is ready to help',
#  'applebees introduces new 50 appetizers for $250 special',
#  'woman googles hangover cures in case there been any scientific breakthroughs since last weekend',
#  'ron desantis clarifies that monkey comment was intended as subtle enough dog whistle to get away with',
#  'child decides to become vegetarian after forming close friendship with roasted turkey leg',
#  'man charged $26 million for damaging picasso painting in london',
#  'ge releases new flickering light bulb for abandoned sanatoriums',
#  'as curfew is lifted, baghdad is at long last partying again',
#  'confederate battle flag sales boom after charlottesville clash',
#  'cory booker apologizes to wall street bankers for the mean things hes going to have to say about them',
#  "khloe kardashian paternity claim: o.j. simpson’s manager says former nfl player 'could be' the reality star’s biological father",
#  'giddy tim kaine presses face against campaign bus window as horse trailer drives by',
#  'el chapo extradited to u.s.',
#  "policeman who asked to smell woman's feet arrested.",
#  'carl bernstein weeps uncontrollably after learning bob woodward wrote a president book without him',
#  "jussie smollett's brother says he's suffering night terrors over 'attack' - imdb",
#  'restaurant owner dumpster diving for deer parts accused of selling them in nyc',
#  'mass underwater orgies creating orgasms so loud it’s causing deafness',
#  'how to lose belly fat effective tips for women',
#  '"no way to prevent this" says only nation where thus regularly happens',
#  'massachusetts college removes american flag from campus',
#  'house stenographer dragged off floor yelling about freemasons and god.',
#  'man nostalgic for simpler era of 20 hours ago',
#  'internet angry at steven spielberg for murdering triceratops',
#  'poll: only 4 in 10 republicans think trump mentioned biden on ukraine call even though he acknowledged doing so',
#  'is michael moore really making a movie about an anti-masturbation dolphin called fappy?',
#  'bearded, keffiyeh-clad jared kushner avoids conflict of interest by joining saudi royal family',
#  'woman bakes brownies and a bear tries to break into her home',
#  "11 things your labor and delivery nurse wants you to know but won't tell you.",
#  'dad accidentally films entire vegas vacation with camera pointed at himself',
#  'the first time i discovered i was white',
#  'former mormon youth leader elaine dalton laments the ‘unladylike’ behavior of women’s marchers',
#  'men fired in wake of #metoo come forward about how it took them several hours to find new jobs',
#  '22-ton bridge stolen from turkish village',
#  'once they put me on cheeses, i will finally be happy, says costco employee handing out free vienna sausage samples',
#  'asshole taking up two plots',
#  'man approaches unfamiliar shower knobs like he breaking wild stallion',
#  'cedar point offers to rename coaster king james if lebron returns to the cleveland cavaliers',
#  'man shoot himself in the penis',
#  'clinton aide told to leave behind weak volunteer who collapsed during march to south carolina',
#  'social becomes worlds most popular social media site',
#  'coffee shop customer asks if guy at next table would mind watching while he goes to bathroom',
#  'uk postal service tells public to stop putting potato chip bags in the mail',
#  "governor kristi noem launches anti-meth campaign 'meth. we're on it.'",
#  'tax preparation software vs. hiring an accountant',
#  'sex on mars will be difficult, study finds',
#  'indian student went to join the islamic state, but all he got was this lousy job cleaning toilets',
#  'who sent you here, whispers woman to big tray of cheese danishes confronting her in break room',
#  'man going to restroom deputizes friend to order him another beer',
#  '"the red maga hat is the new white hood" - alyssa milano compares maga hats to being in the kkk',
#  'scientists teach father to communicate emotions using rudimentary hand gestures',
#  '$160k of cheese stolen in wisconsin in two separate thefts',
#  'kamloops woman sues b.c. cannabis stores claiming mislabelled pot messed up her study session',
#  'usb 3.1 gen1, formerly usb 3.0, formerly usb superspeed, will now be called usb 3.2 gen1',
#  'hr director reminds employees that any crying done at office must be work-related',
#  'nation leery of very odd little boy',
#  "hillary allows men at 'women-only' event amid weak turnout",
#  'going-out-of-business sign thanks neighborhood for 3 months of no support whatsoever',
#  'the elf on the shelf is preparing your child to live in a future police state, professor warns',
#  '2 associates of giuliani indicted on campaign finance charges',
#  'report: your father currently typing naked women into yahoo images search bar',
#  '6 pak - x factor',
#  'teen crashes into license center building during driving test',
#  'running late to meeting, man paddleboards across hudson river in business suit, dress shoes',
#  'overturned semi dumps 40,000 lbs of chicken feathers on the highway',
#  'wanted man jumps from porch, lands in police hands',
#  'local clan attempts to intimidate rivals with aggressive display of fertility',
#  "citadel kkk controversy: students to be suspended for wearing white hood 'ghost' costumes",
#  "'last afghani jews' kicked out of taliban prison for being too annoying",
#  'new york bill tries to get tide pods to look less edible',
#  'rodium x’czar juhu',
#  'man putting off starting family to focus on treading water in career for few years',
#  'lông nách phụ nữ rậm rạp có phải là nguyên nhân gây mùi hôi nách?',
#  'man still trying to find right work-anxiety–life-anxiety balance',
#  'breaking: ballistic missile attack alert was a mistake',
#  'queen elizabeth unnerved by stephen millers requests to sample royal baby',
#  '"all a bit predictable": sean bean now rejects roles where his character dies on screen',
#  'cory booker drops out of 2020 rat race after falling in love with small-town iowa life',
#  'cambridge analytica whistleblower admits last few weeks at work have been awkward',
#  'gerbil running late will have to eat her babies on the go',
#  "in court, 'flume dog' may have his day",
#  'tips for choosing the right veterinarian',
#  'barbara bush dies at 92',
#  "epic crash with 'sausage' galaxy shaped milky way's bulge",
#  'keith richards housekeeper has braced herself for finding dead body every morning since 1976',
#  'thousands of students forced to attend iowa state after university sets acceptance rate to 140%',
#  'weeping tim cook spotted screaming for help at steve jobs tombstone',
#  '2 arrested in alabama buffet brawl over crab legs',
#  'revlon unveils new age-defying monster makeup',
#  'the week in pictures – week of february 25, 2019',
#  'indonesian man who helped set strict adultery laws flogged for adultery',
#  'new york inferno sparked by amateur bladesmith',
#  'no wainting swimming pools',
#  'u.s. government offers 100 million americans generous severance deal to leave country',
#  'christian bus driver says he’ll quit if he has to drive calgary’s pride-themed rainbow bus',
#  'drug driver caught with child sitting on his lap, allegedly claims child was the one driving',
#  'for defense against active shooters, university hands out hockey pucks',
#  'how forex trading changed my life',
#  'pat patriot denies being mascot #5 in prostitution sting police report',
#  'is football bad for the nfl?',
#  'bus passenger risked sydney harbour bridge inferno to tap off opal card',
#  'michael cohen promises more damaging recordings of trump already public',
#  'deutsche bank begins removing possessions from white house after trump defaults on loan',
#  'parents officially designate upstairs television for anyone who doesnt want to watch thanksgiving football',
#  'man shoots and kills wife, blames his fear of black lives matter',
#  'my boyfriend is wonderful and loving – but he has a tiny penis',
#  'sports news in brief witnesses to gordon hayward injury continuing long road to recovery',
#  'john urschel, ravens offensive lineman, publishes math paper',
#  'green day bassist has bass lessons for the first time',
#  'australia zoo urges people to catch deadly spiders as antidote runs low',
#  'gop officials: kavanaugh shouldnt be held accountable for something he did as white teenager',
#  '95-year-old man teaches other seniors how to fall',
#  'original voice of nba buzzer passes away',
#  'wide reciever corey coleman could be out until training camp after falling on football',
#  'female trump supporters just feel more comfortable with gop candidate whos openly horrible to them',
#  'eating cheeseburgers may give crows high cholesterol: study',
#  'yes lyrics to be added to new testament',
#  "un shocked by level of poverty in alabama: 'we haven't seen this in the first world'",
#  'report: middle east quickly running out of land area for violence to spill over to',
#  'pros and cons of standing desks',
#  'report: it pretty incredible that americans entrusted with driving cars',
#  'environmentalists warn swedish fish population being decimated by great pacific sour patch',
#  "sheffield united fc funded by a £3m loan from osama bin laden's family, court hears",
#  'marshmallow or meanie pants?',
#  'boy, 12 , has surgery to remove 39 magnetic balls from penis',
#  'uzbekistan bank robbers labour for tiny haul',
#  'mussels of the coast of seattle test positive for opioids',
#  'iranian scientist annoyed he has to go back to shitty old job building nuclear weapons',
#  'ethiopia end the internet censorship',
#  'nudist campers worry i-69 will ruin their solitude',
#  'woman leaps to death off rooftop bar, patrons keep drinking',
#  'british woman’s belly button explodes on plane',
#  'newt gingrich: its an honor to address a crowd that shares my utterly bizarre and unhealthy obsession with hillary clinton',
#  'walmart veteran says congress needs more former cashiers',
#  'donald trump wins us election',
#  'resistance democrat racking brain for way to sexualize anonymous whistleblower',
#  'farty passenger forces flight to make emergency landing',
#  "14-year-old boy arrested for posing as new york city officer while snatching legally blind man's wallet in manhattan subway station",
#  '5 things to know about the man who killed don quixote',
#  'they cant impeach someone they cant see, say trump boys cramming dad into homemade bunker under oval office desk',
#  'kanye west is now an honorary doctor',
#  '5 things to know about richard spencer',
#  'fed up of kids not studying, mother poisons them, self in mumbai',
#  'half-empty bottle of colt 45 left on church steps must be offering to god',
#  'upstate college to offer course on miley cyrus',
#  'spotify reaches 100 million paying subscribers',
#  'report: make it stop',
#  'lester holt begins debate by reminding audience these the candidates they chose',
#  'canadian holocaust monument omits any mention of jews',
#  '“decapitate her head off”: phil robertson’s vile message to atheists',
#  "nikki haley to fox news: world leaders laughed at trump out of 'respect'",
#  ...]

# %%
display(pipe.score(X_train.map(lambda x: nlp_lg(x)), y_train))
display(pipe.score(X_test.map(lambda x: nlp_lg(x)), y_test))
display(pipe.score(theonion_holdout["title"].map(lambda x: nlp_lg(x)), theonion_holdout["is_onion"]))
display(pipe.score(nottheonion_holdout["title"].map(lambda x: nlp_lg(x)), nottheonion_holdout["is_onion"]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-2bad724f0796> in <module>
# ----> 1 display(pipe.score(X_train.map(lambda x: nlp_lg(x)), y_train))
#       2 display(pipe.score(X_test.map(lambda x: nlp_lg(x)), y_test))
#       3 display(pipe.score(theonion_holdout["title"].map(lambda x: nlp_lg(x)), theonion_holdout["is_onion"]))
#       4 display(pipe.score(nottheonion_holdout["title"].map(lambda x: nlp_lg(x)), nottheonion_holdout["is_onion"]))
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\metaestimators.py in __get__(self, obj, type)
#     108                     continue
#     109                 else:
# --> 110                     getattr(delegate, self.attribute_name)
#     111                     break
#     112             else:
#
# AttributeError: 'predictors' object has no attribute 'score'
