# %% [markdown]
# # `spaCy`
#
# In this notebook, we explore using the python library `spacy` to enhance our analysis.
#
# We ran into implementation issues, so there is no useful modelling in this notebook. Feel free to skip forward to the next.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import pickle

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.naive_bayes import MultinomialNB, GaussianNB
# Import CountVectorizer and TFIDFVectorizer from feature_extraction.text.
from sklearn.feature_extraction.text import CountVectorizer,\
                                            TfidfVectorizer


from sklearn.base import TransformerMixin

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer
from nltk.stem.porter import PorterStemmer

# %%
def save_obj(obj, filename):
    with open(filename + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(filename):
    with open(filename + '.pkl', 'rb') as f:
        return pickle.load(f)

# %%
DIR = "C:\\Users\\AzNsAnTaGiN\\DSI\\Projects\\project_3\\data\\"
FILE1 = "theonion"
FILE2 = "nottheonion"
FILE3 = "onionheadlines"

# %% [markdown]
# # Data Import

# %%
X_theonion = load_obj(DIR+FILE1+"_df_clean")
X_nottheonion = load_obj(DIR+FILE2+"_df_clean")

# %%
X_theonion["is_onion"] = 1
X_nottheonion["is_onion"] = -1

# %% [markdown]
# # Tokenizing with `spacy`
#
# We follow along with the tutorial found here
# https://www.dataquest.io/blog/tutorial-text-classification-in-python-using-spacy/

# %%
import spacy

from spacy.lang.en import English
from spacy.lang.en.stop_words import STOP_WORDS
import en_core_web_sm, en_core_web_lg

import string
puntuations = string.punctuation

# %%
nlp_sm = en_core_web_sm.load()
nlp_lg = en_core_web_lg.load()

# %% [markdown]
# The following code, which merges tokens that are part of the same spacy `entity`, comes from https://stackoverflow.com/questions/54640715/tokenizing-named-entities-in-spacy

# %%
class EntityRetokenizeComponent:
  def __init__(self, nlp):
    pass
  def __call__(self, doc):
    with doc.retokenize() as retokenizer:
        for ent in doc.ents:
            retokenizer.merge(doc[ent.start:ent.end], attrs={"LEMMA": str(doc[ent.start:ent.end])})
    return doc

retokenizer = EntityRetokenizeComponent(nlp_lg) 
nlp_lg.add_pipe(retokenizer, name='merge_phrases', last=True)

# doc = nlp_lg("German Chancellor Angela Merkel and US President Barack Obama "
#           "converse in the Oval Office inside the White House in Washington, D.C.")

# [tok for tok in doc]

# %% [markdown]
# The following code, which implements some lemmatization, comes from https://www.dataquest.io/blog/tutorial-text-classification-in-python-using-spacy/

# %%
stop_words = spacy.lang.en.stop_words.STOP_WORDS

parser = English()

def spacy_tokenizer(sentence):
    mytokens = nlp_lg(sentence)
    
    #lemmatize
    mytokens = [ word.lemma_.lower().strip() if word.lemma_ != "-PRON-" else word.lower_ for word in mytokens]
    
    #prune stopwords and punctuation
    mytokens = [word for word in mytokens if word not in stop_words and word not in puntuations]


class predictors(TransformerMixin):
    def transform(self, X, **transform_params):
        # Cleaning Text
        return [clean_text(text) for text in X]

    def fit(self, X, y=None, **fit_params):
        return self

    def get_params(self, deep=True):
        return {}
    
def clean_text(text):
    return text.strip().lower()

# %% [markdown]
# Now in the future we can call our methods with `tokenizer = spacy_tokenizer`, and add a `("cleaner", predictors())` preprocessing step to our pipeline.

# %%
X_theonion["title"].head(1)
# Out:
# id
# 79mcv    Microsoft Ad Campaign Crashing Nations Televis...
# Name: title, dtype: object

# %% [markdown]
# # Taking spacy for a spin
# Now that we have a preprocessing workflow, let's see if it improves anything.

# %% [markdown]
# ## Generating our samples and holdout

# %%
N=4000
X_theonion_shuffled = X_theonion.sample(len(X_theonion))
theonion_sample = X_theonion_shuffled.head(N)
theonion_holdout = X_theonion_shuffled.tail(len(X_theonion_shuffled) - N)

X_nottheonion_shuffled = X_nottheonion.sample(len(X_nottheonion))
nottheonion_sample = X_nottheonion_shuffled.head(N)
nottheonion_holdout = X_nottheonion_shuffled.tail(len(X_nottheonion_shuffled)-N)
X_sample = pd.concat([theonion_sample, nottheonion_sample])
X = pd.concat([X_theonion, X_nottheonion])

# %% [markdown]
# # TF-IDF + Logistic Regression

# %%
X_train, X_test, y_train, y_test = train_test_split(X_sample["title"], X_sample["is_onion"])
pipe = Pipeline([
    ("cleaner", predictors()),
#     ("tfidf", TfidfVectorizer(tokenizer=spacy_tokenizer)),
#     ("logreg", LogisticRegressionCV(Cs=np.logspace(-2,2,100), max_iter=1000))
])
pipe.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('cleaner',
#                  <__main__.predictors object at 0x0000025600C71B88>)],
#          verbose=False)

# %%
pipe.transform(X_train)
# Out:
# ['swedish government launches major study into sex lives of its citizens',
#  'parent of middle school students amid shooting: ‘this happens in high school, not here’',
#  'parents trying to gauge if son complete idiot before deciding whether to move to better school district',
#  'the last of us 2 to be released in 2019',
#  'pregnant woman kicked out of flight after plane deemed too heavy',
#  'deal alert: your parents have promised to buy you lets go pikachu if you can make it through rosh hashanah this year without biting anyone',
#  'tim duncan proudly reflects on all the degrees he accumulated during 19-year nba career',
#  "burger king 'sorry' for offering burgers to women who get pregnant to world cup players",
#  'female friend group fails in one duty of providing good gynecologist recommendation',
#  'gold coast police hunting mullet man with face tatts over alleged sex toy theft',
#  'feds say chinese ownership of grindr is a ‘national security risk’',
#  'man accused of burgling home, painting dog purple',
#  'victorias secret releases sexy black lace sleep apnea mask',
#  'seating mix-up puts tony bennett in middle of slipknot',
#  'scientists successfully create artificial placenta that tastes just as delicious as real one',
#  'trump locked out of white house after accidentally revoking own security clearance',
#  'lebron james reveals school he founded has seen huge gains in english, math, and dunk testing',
#  'customer who declined initial offer of assistance from floor salesman comes crawling back',
#  'decorated officer caught having sex with cows. arrested. let go free of charge',
#  'restaurant owner shoots at customer over disputed bill',
#  'trump fans whine about reports on baby jails: ‘quit trying to make us feel teary-eyed for the children’',
#  'trump supporter has few backup scapegoats ready to go in case crackdown on immigrants doesnt fix everything',
#  'david remnick quietly relieved he wont have to lose debate to steve bannon in front of everyone',
#  "'shamboiling': the newest drug trend among teens.",
#  'doctor asks patient if he would mind having medical student, some of his poker buddies in room for exam',
#  'obama leaves post-it on counter with quick note explaining how to use extralegal surveillance apparatus',
#  'revealed: the most dangerous biscuit in britain is.. the custard cream',
#  'britney spears music used to scare away somali pirates',
#  'fbi shuts down prominent new isis recruitment website',
#  'primate rampage: monkeys rip up voter lists in thailand',
#  'wellington pub green man puts stag semen on menu',
#  "teacher 'swallowed whole' by shark while fishing with friends off south australia coast",
#  'poll finds majority of americans approve of child labor laws but agree that kids carrying briefcases would be cute',
#  'report: growing number of americans forced to make ends meet by collaborating on song with pitbull',
#  'sarah palin can still see russia, promises to keep an eye on them',
#  'coworker wondering if anyone interested in laying bare their physical shortcomings in basketball league this year',
#  "russia's former anticorruption police chief sentenced to 22 years for corruption",
#  'new era introduces new spiked baseball caps to keep pigeons from landing on players heads',
#  'scientists developing marijuana breathalyzer to catch stoned drivers',
#  "brazil's new racetrack is a minefield... literally",
#  'silent discos face ban by edinburgh city council because they’re ‘too noisy’',
#  'shia labeouf got two missy elliott tattoos out of ‘peer pressure’',
#  '"artist always carries around sketchbook in case he feels like making someone uncomfortable"',
#  'woman badly burned after passing gas during surgery, igniting laser',
#  'partisan differences set aside for congresss annual erotic masquerade ball',
#  'papa john sues papa john’s',
#  'man gets stuck in air duct while hiding from cops, gets hypothermia',
#  'naked man refusing to let unworthy attire touch his body until launch of new store merchandise',
#  'hentai message board features surprisingly close-knit, supportive community',
#  'kc masterpiece ceo warns against societys increasing reliance on a1',
#  "aussie athletes to be issued zika-proof 'super condoms' in brazil",
#  'the nazis and zionists helped jews emigrate to palestine.',
#  "ted cruz eats greasy pig cooked on a 'machine gun'",
#  'patriots tired of jimmy garoppolo beginning every huddle with this is my team now',
#  'elderly man whos outlived wife by 8 years must not have loved her very much',
#  'report: what you just said reminds man of thing hed rather talk about',
#  'ben carson mistakes a common real-estate term for a cookie.',
#  'til a team of thieves stole $18,000 worth of tracking devices from a warehouse. they were apprehended within hours',
#  'nfl announces super bowl tickets only available for purchase one hour before kickoff at stadium box office',
#  'a piece of history is found in the rear end of a jesus statue',
#  'police gunned down a 12-year-old and somehow local news decided to run story about father.',
#  'jeff bridges seated directly behind support column at golden globes',
#  'metta world peace formerly known as ron artest is changing his name to “panda friend”',
#  'local - all autistic children are atheists and atheism is a form of autism, says association head',
#  'man gets hypothermia after hiking up snowy mountain for free pizza',
#  'gop candidate john kasich vows to reunite pink floyd',
#  'i dont support feminism if it means murdering all men',
#  'russian man dies after posing for photo with hand grenade',
#  "beaver 'at large', warns rcmp after unusual accident in priests pond",
#  'snapcat, an app that lets cats take selfies by pawing the screen',
#  "maine police 'not joking' about beaver-eating snake on the loose",
#  'failure to get into private college to be most financially responsible act of 17-year-olds life',
#  'mike pompeo cant believe senate just expects hell answer questions without being tortured first',
#  "girl injured following fall when 'tram surfing' settles personal injury claim for €550,000",
#  'soldier excited to take over fathers old afghanistan patrol route',
#  "woman's body acts as a brewery so judge dismisses dwi.",
#  'becoming a mother has been the most thrilling experience of my life, reports woman fleeing hospital with stolen baby',
#  'pros and cons of banning bottled water',
#  'the simpsons predicted it being bought by disney two decades ago',
#  'if darth vader can destroy cities, so can superman, zack snyder says',
#  'family spends relaxing weekend destroying outdoors',
#  'fun toy banned because of three stupid dead kids',
#  'nation shudders to think how mad nra would be if obama actually proposed meaningful gun control',
#  'flakes on a plain',
#  'university of toledo deleted tweet about changing mascot to shrek',
#  'world cup 2018: russian lawmaker warns against sex with foreigners',
#  'cops mourn loss of doughnut truck - cnn video',
#  'donald trump tosses rolls of paper towel to puerto rican residents like they are basketballs',
#  'the internet was obsessed with this philosophy-quoting homeless man in china. now he’s fled the fame.',
#  'would-be burglar calls 911 after getting stuck on roof of home',
#  '2016 in the economy',
#  'dubai airport welcomes saudi jet with water cannon salute, breaks plane',
#  'theres been an explosion!',
#  "trump on kim jong un: 'he wrote me beautiful letters. we fell in love'",
#  'activists stop paying their student loans',
#  'calumet farms unveils new tandem horse for couples riding',
#  'lubbock woman blinded after using flea market contact lenses',
#  'child wondering why older brother only one to get funeral',
#  "dad auctions off his son's football allegiance.",
#  'china bans all types of fentanyl',
#  'out-of-control hand gesture sends bernie sanders tumbling off stage',
#  'french court stops child from being named nutella',
#  'chuck schumer "loses cool" with trump supporters in swanky nyc restaurant',
#  'department of transportation introduces padded bumper lane for intoxicated drivers',
#  'clinton throws flash grenade to divert attention from question about senate voting record',
#  'coca-cola may move into marijuana products',
#  "norwegian village without a pokestop installs 'pokemon go' statue",
#  'hawthorne robbery suspect accidentally shoots himself when victim runs him over',
#  'snake on a plane forces aussie pilot to make emergency landing',
#  'student suspended for shaping pop-tart into gun [x-post r/news]',
#  'and then those 12 people send it to 12 people—thats 144 people!” says cory booker describing campaign newsletter strategy to rosario dawson',
#  'macys announces store closures, layoffs',
#  'cbs to retain les moonves services in smaller sexual-predator-at-large role',
#  'big rig drags minivan 16 miles after snowy accident',
#  'dunkirk survivor praises film as most realistic depiction of cowardly fleeing from battle',
#  'spam heists in hawaii prompt retailers to put the wildly popular ‘mystery meat’ in locked cases',
#  'berkeley campus on lockdown after loose pages from wall street journal found on park bench',
#  'nfl announces new zero-tolerance policy on videotaped domestic violence',
#  'new hampshire school district bans dodgeball because of sandy hook',
#  'hillary clinton: young girls should have an equal opportunity to one day feel power coursing through their body',
#  'ukraine’s dolphin army goes on hunger strike',
#  'mom much more insistent about getting grandkids from one child than other',
#  'vive ‘le pong!’: foul french smell prompts emergency response',
#  'domino’s workers come to customer’s rescue after noticing he hadn’t ordered pizza recently',
#  'nth korea declares war on seth rogan',
#  'pewdiepie to stop making nazi jokes after realizing that nazis are real',
#  'chuck grassley scratches christine blaseys a slut into senate bathroom stall',
#  'kanye west gives rambling, 20-minute speech at shoe event from @ap',
#  'india man to sue parents for giving birth to him',
#  'netflix adds thousands of mediocre new subscribers',
#  'mounted police officer rides through drive-thru on horseback',
#  'woman, 21, sets ex-girlfriend’s truck ablaze before shooting self.',
#  'trump tower in vancouver renamed ‘dump tower’ on google maps',
#  'harpoon industry attempting rebrand by pointing out harpoons can harpoon stuff besides whales',
#  'suffering blue whales plead with environmentalists to let them go extinct already',
#  'jammu and kashmir bans big fat weddings, puts cap on number of guests, dishes',
#  'disconcerted woman has no memory of telling dressing room attendant her name',
#  'coach accidentally sends masturbation video to team',
#  'loose-cannon cop who doesnt play by the rules uses unconventional filing system for paperwork while on desk duty',
#  'james comey quickly reopens clinton email investigation for few more minutes',
#  'the academy awards: honoring the greatest achievement in shameless self-indulgence',
#  'police have had to be reminded they can’t charge dead people',
#  'student arrested for repeatedly mailing poop to vice principal',
#  'i slapped a crying child and called him a nigger and im the bad guy?',
#  'biden campaign concerned after candidate gives unsolicited back rub to coat rack',
#  'south oxhey man mark waterfall gets 20 years for shooting watford doctor with crossbow',
#  'harvard streamlines admission process by directly growing new students from dna of top donors',
#  'this shooting isnt about gun control we refuse to pass, its about access to mental health care were continuing to gut',
#  'study: red meat takes years off of cows life',
#  '6 castles that cost less than an appartment in nyc',
#  'couple suffers miscarriage shortly after pregnancy announcement goes viral',
#  'first they go after our bobby b and now our coke!',
#  'ted cruz pledges support for constitutional amendment banning birth control',
#  'walgreens unveils new line of shrink-wrapped sandwiches to grab when something has gone horribly, horribly wrong',
#  'uber driver napped as his passenger led highway chase',
#  "women's institute members dress as pirates during lecture from capt. darch, held hostage by somali pirates for 47 days",
#  "pornhub begs users to stop uploading videos of 'germany f**king brazil'",
#  'hockey pucks currently being used to protect against active shooters',
#  'jewelry company jumps gun with engagement ring commercial featuring polyamorous triad',
#  'researchers publish list of ways animals can help fight climate change',
#  'man accidentally shoots his thumb while trying to kill a porcupine near steptoe',
#  'arne duncan spends visit to local elementary school looking at ufo books in library',
#  "baseball field closed due to 'poor decision' to douse it in gas, set it on fire",
#  'new zealander takes clown to redundancy meeting',
#  'ice opens new supermax detention center for most hardened toddlers',
#  'unhinged lunatic using facebook to spread conspiracy theories',
#  'moderator asks candidates to be specific when describing hellscape country will become if they not elected',
#  'judge sentences lori loughlin to 100 hours of community theater',
#  'wolfeboro man threatens wife, police',
#  'democrats call for trump impeachment',
#  "absolute monarch renames swaziland 'eswatini'",
#  'tom steyer upgrades to luxury-class debate section with hot towels, beverage service',
#  'retired couple realizes dream of buying camper, driving around country murdering hitchhikers',
#  'driver charged for putting seatbelt on beer instead of children',
#  '5 things to know about captain marvel',
#  "apple's new 'iwatch' could land you two years in jail",
#  'xác lập kỷ lục tượng phật bằng hoa bất tử lớn nhất thế giới - chuyên mục phụ nữ - blog phái đẹp',
#  'dutch man loses bid to change his age, plans to appeal',
#  'nestlé pulls out of iaaf sponsorship deal over public-image concerns',
#  'mother annoyed son playing video games on beautiful day when he could go outside to kill people',
#  'dunbar family forced to discontinue print edition of christmas newsletter',
#  'woman who drinks 20 cans of air freshener every week is warned her habit could kill her',
#  'mike pence horrified by d.c. cherry trees flagrantly displaying reproductive organs',
#  'serial killer admits hes lost track of pattern he was going for originally',
#  'yes, a sinkhole has opened up on the white house lawn',
#  'scientists approve gene editing in embryos',
#  'intimate scheduled to be released in february, escaped.',
#  "arizona's pastor steven anderson argues that aids would be eradicated if gays were 'executed'",
#  'trump delivers anecdote about small business owner who isnt half the man he is',
#  'hillary, bill clinton to attend inauguration',
#  'man arrested after liking his own wanted photo on crime stoppers page',
#  'facebook clarifies site not intended to be users primary information source',
#  'concerned nation gently encourages boston to take it easy this st. patricks day',
#  'helpful waitress asks recently seated couple if theyve eaten food before',
#  'man old enough to know how rest of life pretty much plays out',
#  'fbi surveillance reveals terrorist-linked cleric anwar al-awlaki had a taste for pizza and call girls',
#  'mattel preempts backlash over gender-neutral doll with release of new covered in genitals barbie',
#  'roger federer fan who woke from 11 year coma shocked fed still good',
#  'christies auctions off stephen hawkings wheelchair, thesis paper',
#  'double-jointed man attacks officer despite being handcuffed',
#  'oxycontin billionaire to sell drug to get you off oxycontin',
#  'gop worried its minority outreach was accidentally racist',
#  'area liberal no longer recognizes fanciful, wildly inaccurate mental picture of country he lives in',
#  'shamefaced man stands stock-still as acquaintance zips up backpack for him',
#  'of all the things to "crack down" on...',
#  "south korea's coach made players swap shirts in recent friendlies to confuse opponents who he says cannot tell them apart",
#  'fed-up eu rejects united kingdom, gives british 30 days to vacate europe',
#  'clothes come to forefront as major theme in this years new york fashion week',
#  'state dept. memo warning employees against leaking is immediately leaked',
#  'cork airport evacuated over burnt toast.',
#  '14-year-old running for vermont governor: ‘my message and my platform transcend age’',
#  'atlanta plans change to names of streets honoring confederacy',
#  'the great mattress migration of 2019',
#  'ruth bader ginsburg returns to supreme court after surgery',
#  'ole miss loses to mississippi state after urinating dog celebration',
#  'suspect farts loudly enough to give away hiding place to police liberty, mo',
#  'brett kavanaugh reiterates cruel and unusual punishment what makes someone a true kappa',
#  'police: woman steals cheese, beer, sprays perfume, leaves cellphone at scene of burglary',
#  'panicked meteorologists advise entire nation to take cover after losing track of hurricane michael',
#  'god knocked unconscious by directtv satellite',
#  "kellyanne conway, on trump's inauguration day, wears coat with cat buttons",
#  'man watches helplessly as white elephant exchange completely devolves into friends just chatting and having nice time',
#  'man confused by compliment from person whose career he cant help',
#  'i only like movies where the whole cast dances in a little box next to the end credits',
#  'raffi apologizes to the new pornographers',
#  "rapist is let off for sexually attacking a woman after agreeing to allow his sister to be raped by his victim's brother in pakistan",
#  "mom drives with son on vehicle's hood after dentist office panic, cops say",
#  'mom wants to know if youll be free if she visits 14 months from now',
#  'bigot annoyed local mosque already vandalized before he got there',
#  'airport only place in metro area to buy citys signature food',
#  'deputies free bear stuck in car',
#  'cmon, cmon, says matt damon desperately searching for own name on list of imdb user dolphinsoul60s top 100 actors',
#  'baby can already tell crib hes in going to be recalled',
#  'god irritated guests do not understand it time to leave heaven',
#  'chicago police officer is now suing the family of the man he killed',
#  'poll finds 54% of americans approve executing trump but leaving him in office',
#  'chase ceo giving commencement speech pledges to double whole classs student loan debt',
#  'all-business adult in halloween shop beelines it straight for pinhead mask',
#  'sessions vows to protect all deeply held religious bigotry',
#  'whats all this im hearing about people getting security clearances? asks confused mike pompeo to white house staff avoiding eye contact',
#  'tennessee lawmakers endorse bid to declare all marriage illegal in order to spite equality',
#  'new doctors without licenses program provides incompetent medical care to refugees',
#  'man on vacation suddenly realizes no one feeding his hostages',
#  'gaunt, hollow-eyed big bird enters sixth day of hunger strike against proposed trump budget',
#  'facebook announces plan to combat fake news stories by making them actually happen',
#  '[hong kong] live ww1-era german hand grenade found in a shipment of potatoes from france',
#  'community a wasteland of professional athletes failed side businesses',
#  'this bitter couple tells us the secret to a 3-year, 5-month, and 2-week marriage',
#  'stupidity at its very finest.',
#  '13.5 million americans tune in to watch animal planets puppy parlay during dnc debate halftime show',
#  'retired pope benedict pledges to donate soul for ecclesiastic research',
#  'rogue pigeon boards c train in brooklyn, chaos ensues',
#  'study reveals lobsters feel pain and get off on it like the kinky little perverts they are',
#  'nonessential government employee gets back to work',
#  'welfare emerges as the savior of the housing crisis',
#  "british prime minister accused of putting genitals in dead pig's mouth",
#  'nude florida women were ‘air drying’ at rest stop, police say, before leading them on wild chase',
#  'autistic teenager tipped for nobel prize',
#  'political ad spending hit new record in 2018 midterms',
#  'penis amputated by chinese man depressed about his love life [semi-nsfw]',
#  'man accused of throwing 13-foot-long python at sushi bar customers in studio city',
#  'university head urges students to carry guns',
#  'how can i use feminism to my advantage?',
#  'mass. police advise against chasing bears with dull hatchets while drunk',
#  "chechnya's leader kadyrov urges men to lock up their wives, ban women from whatsapp",
#  'new neutrogena extra-strength face wash instantly dissolves bad skin',
#  'financial planners suggest spending one evening each week ripping apart walls, floorboards in search for cash',
#  'falling tape measure kills man at jersey city construction site',
#  "the handmaid's tale launches line of wines",
#  'calif. girl who was declared brain-dead to get diploma',
#  'zach braff, alyssa milano call out trump for far more effectively pivoting to politics to save floundering career',
#  'man suddenly regretting asking to be taken seriously by peers',
#  'woman claims united airlines flight attendants made her urinate in a cup',
#  'man leaving caffeine dispensary on the way to alcohol dispensary disgusted by marijuana dispensary',
#  'health experts say tackle football poses little risk for children whose brains already dont work that well',
#  "danny devito as wolverine? more than 13k fans sign petition to make it happen: 'he is the obvious choice here'",
#  'fucking idiot has perfect gif for that',
#  'aggressive flagellate just going around whipping other single-celled organisms',
#  'clint eastwood propositions film critic to obtain more positive review of richard jewell',
#  'edinburgh zoo panda yang guang has testicles removed',
#  'woman trying to prove ‘vegans can do anything’ dies of altitude sickness on mount everest',
#  'election-crazed new york times expands poll coverage to 18.5 million more races in 371 additional states',
#  'trump assures kurds there will one day be very nice tree planted in d.c. commemorating their deaths',
#  'are our nominations diverse enough for you whiny dipshits? sneers academy president unprovoked after listing nominees',
#  'praying mantises get fitted with 3d glasses, watch bug movies',
#  'unemployed prince harry, meghan markle announce plans to give baby up for adoption',
#  '76-year-old tries to attack son with chainsaw, son runs him over with lawn mower',
#  'parents gently explain to son why family dog had to be blown up with dynamite',
#  'researchers observe chimpanzees using pro tools',
#  'tiny gecko manages to make ‘a bazillion’ calls from seal hospital',
#  'county commission: flags to fly less than half-staff over gay marriage ruling',
#  'dogs relief to finally get to pee for first time in 9 hours mistaken for excitement to see owner',
#  'pope francis declares abortion forgivable',
#  'dutch f-16 flies into its own bullets, scores self-inflicted hits',
#  '9 things introverts do all the time',
#  "okc thundercomplete thunder coverage convicted felon, doctor injects oklahomans with 'jesus shot'",
#  'dutch police are training eagles to take down rogue drones',
#  "westfield woman says neighbor vandalized flowers saying, 'these are for your funeral'",
#  'manafort clearly attempting to send judge encrypted whatsapp messages while waiting in courtroom',
#  'woman caught on camera defecating on floor of a tim hortons and throwing feces at an employee',
#  "apple's executive's portraits are now memojis",
#  'tips for working from home',
#  'old lady at parade flapping little american flag like a motherfucker',
#  'upset red sox fan demands to speak to manager',
#  'depressed groundhog sees shadow of rodent he once was',
#  'avocados may run out if u.s.–mexico border closed',
#  'teen pregnancy rate prompting more high schools to eliminate fuck your brains out program',
#  'thousands of rats tumble about uncontrollably inside snoopy balloon high above thanksgiving day parade',
#  'trump: i am a very stupid human being',
#  'kanye west declares war on the pirate bay',
#  'pot-smoking moms say they’re tired of being judged by wine drinkers',
#  'mama duck doesnt recall asking for injured baby to be rescued from road',
#  'comey suddenly realizes entire book just a subconscious defense mechanism to hide his true feelings',
#  'how the candidates are luring delegates',
#  'teens shot sally the llama with bow and arrow, slashed her throat: cops',
#  'lack of sexual tension with coworker almost unbearable',
#  'gudbranson admits it was wrong, not actually going to kill martin',
#  "novelist who wrote about 'how to murder your husband' charged with murdering her husband",
#  'tesla unveils its cybertruck: an angular electric pickup starting at $39,900',
#  'trump privately terrified his sexual assault victims will someday come forward',
#  'local household announces plans to overdo halloween again',
#  'chris wallace receives cease-and-desist letter from trump organization in middle of questioning candidate about groping allegations',
#  'cedar rapids man arrested for calling 911 on police officers',
#  'third amendment rights group celebrates another successful year',
#  'eu could slap 3 billion euro fine on italy for excessive debt',
#  'amazon pulls auschwitz-themed christmas ornaments',
#  'napkinless man with grease-covered fingers realizes he trapped in a prison of his own creation',
#  'kanye west named new face of yeezy',
#  'tv academy ‘inadvertently left off’ emmy nomination for ‘big bang theory’',
#  '5 things to know about the golden globes',
#  'man wondering if there might be some sort of website featuring footage of sexual acts one may view for purposes of self-gratification',
#  'barcelona sign first-ever sponsorship deal... to have logo inside their shirts.',
#  'report: nazi treasure hunters following more realistic retirement plan than 86% of country',
#  'area woman excited to finally experience unbearable loneliness of having her own place',
#  'guy washing hands for full 5 seconds like hes going into surgery',
#  'study: coffee drinkers at far higher risk of having mug crash to floor in slow motion after hearing their father is dead',
#  'general mills releases new lucky charms with 15 percent less leprechaun meat',
#  'volkswagen’s new 300 mpg car not allowed in america because it is too efficient',
#  'ceiling fan transforms apartment without air conditioning into frosty wonderland',
#  "prince charles admits he may never fit into 'budgie smugglers' again as he approaches 70th birthday",
#  'because of course',
#  'masochist dog enjoys being walked around on leash while naked',
#  'buzzfeed ceo gives laid-off staffers parting gif',
#  'interminable nightmare of buying wrong toilet paper in bulk nearly over',
#  'god gets celtic cross tattooed on back',
#  'qatar unveils indentured mascot for 2022 world cup',
#  'the old lady that ruined the infamous spanish fresco of jesus christ claims copyright over it and demands money',
#  'man basks in triumphant glory after purchases line up to exact value of gift card',
#  'christ announces hiring of associate christ',
#  'a bald eagle named uncle sam tried to attack trump during a photoshoot',
#  "cleveland men's argument over sexuality ends in sword attack",
#  'nationâ\x80\x99s schools to ensure bullied transgender students hide in stalls of bathrooms corresponding to biological sex',
#  'nuclear, climate threats keep doomsday clock close to midnight',
#  'how to file a patent',
#  'man puts 1.64 ft long eel in his anus to treat constipation',
#  'new ps4 feature allows user to close eyes and imagine really fun game',
#  'dow drops 600 points over picture of worried stock broker staring at computer screen',
#  "the bay area is so expensive divorced parents can't afford to live separately",
#  'report: universe to end next friday',
#  'thanksgiving affords nation rare opportunity to eat large amounts of food while watching football',
#  'undocumented immigrant population in u.s. falls to 12-year low',
#  'ignorant man who has learned nothing from history excited about star wars: jedi fallen order',
#  'peta wants lion-hunting dentist killed',
#  'classic: why do all these homosexuals keep sucking my cock?',
#  'chastised french minister: i hate caviar and suffer a lobster intolerance',
#  'study finds 12,000 americans die annually in what are made to look like car accidents',
#  "australian political candidate for queensland doesn't oppose islam as a country.",
#  'guide to red dead redemption 2',
#  'bernie sanders agrees to drop out of race in exchange for 13-hour speaking slot at convention',
#  "why jeff sessions may control the fate of wu-tang's secret album",
#  'woman preemptively posts a few good photos of herself online just in case she ever dies in shooting',
#  'department of interior asks for resignation of obama-era elk',
#  'your horoscopes — week of october 16, 2018',
#  "police crack down on 'bacchus ladies'",
#  'scott walker changes locks on wisconsin governors office',
#  'increasingly unwell harvey weinstein arrives to court as jar of ashes',
#  'turkish president erdogan worthy of nobel peace prize',
#  'ters yüz 2015 &lt; fragmanworld',
#  'jeff sessions spits in face of fbi interrogator trying to get him to turn on trump',
#  'im not sure why i should suffer for something i did 10 years ago and would do again in a heartbeat',
#  'chocolate spill covers highway in poland',
#  'timeline of internet bots',
#  'pbs moderators spend first 10 minutes of debate asking candidates for fundraising advice',
#  'olay introduces new line of pre-moisturized skin',
#  'kicking, screaming warren buffett dragged from caesars palace after losing everything at roulette wheel',
#  "dog sentenced to death because he is 'gay' saved at the last minute...and his new owner calls him elton!",
#  'tony romo realizes he should have used ability to read defenses back when he was still playing',
#  'kendall jenner thinks having a famous last name made things harder for her',
#  "pastor tries to beat jesus' record, dies after 30 days of fasting",
#  'north koreans give crystal meth as lunar new year gifts',
#  'soldiers of odin group stage protest against tropical fish at galway aquarium',
#  'teen on birthright trip hadnt expected to see so many dead palestinians',
#  'senior pretty checked out during entire final year',
#  'sean diddy combs changes his name to brother love',
#  'plane carrying 326 passengers diverted after pilot spills coffee',
#  'priest, pastor, and 90 year-old man charged for feeding the homeless in florida',
#  'nashua’s campbell issues apology over duck deaths',
#  'windows toolbar, mouse cursor visible throughout memorial service slideshow',
#  'gerrymandering mishap leaves nation without any borders whatsoever',
#  'notable hidden bank fees',
#  "'eat' water, don't drink it - experts",
#  'duo, in for forgery, walk out of jail after faking legal documents',
#  'security minister: porteños should leave the city on g20 long weekend',
#  'scotland yard frees 163-year-old british man after dna evidence clears him of being jack the ripper',
#  'guest searches hand towel for low-traffic area',
#  'sean spicer given own press secretary to answer medias questions about his controversial statements',
#  'trump boys ransack muellers office to steal answer key to questions for their dad',
#  'nra praised for decreasing stigma of mentally ill acquiring firearms',
#  "trump seizes on soggy paper straws as campaign issue: 'make straws great again'",
#  'tyson foods sends cease-and-desist to trump for using slaughterhouse recordings as pump-up anthem at rallies',
#  'the number of moped-related crimes in london has increased by 30 times in five years.',
#  'oregon’s ‘klepto kitty’ steals neighborhood weed',
#  "'what plot?' noel edmonds defiantly defends himself after he's accused of 'losing it' over his new motivational phone service for pets",
#  'cash-strapped oklahoma to conduct executions by hammering squad',
#  "new obamacare replacement bill is being hidden in a basement, out of view of public, and even this gop senator can't see it",
#  'nations ivy leaguers share hearty laugh that dartmouth grad thinks she can talk shit on anyone',
#  'taylor swift has escaped the sacramento zoo',
#  'report: pickup basketball player too sweaty to guard',
#  'kansan comes to omaha for at least one garth brooks show, but stays for all six',
#  'lucrative new oil extraction method involves drilling directly into gas stations',
#  "boy, 2, 'castrated' after surgeons operate on wrong testicle",
#  'the week in pictures – week of october 29, 2018',
#  'thom yorke admits vast majority of musical output fueled by constant fear of being one-upped by coldplay',
#  'woman who drinks 6 cups of coffee per day trying to cut down on blue light at bedtime',
#  'study: 90% of bike accidents preventable by buying car like a normal person',
#  'im sort of the abusive mom of my friend group',
#  'man thinks going to vegas for things other than gambling somehow less sad',
#  'man rescued trying to sail to us in £300 dinghy',
#  'jazz reminds fans racist, homophobic language has no place in good seats',
#  'hotshot commencement speaker jumps straight into speech without even defining courage',
#  "how to tie your shoes. and how to lace them, while you're at it. because you've been doing it wrong.",
#  'mass dab for a kid who died in his sleep',
#  'i dont know who i am anymore, little buddy! says mother in midst of nervous breakdown',
#  'state supreme court justice warns he may abolish marriage entirely if same-sex weddings are allowed',
#  'god feeling down in dumps after death of grandmother',
#  'sa man throws ax at moving train, which bounces back, hits him in head, sapd says',
#  'spotify may allow unlimited ad skipping for free users',
#  'federal judge pencils blocking trumps unconstitutional executive orders into monthly schedule',
#  'man who meowed at brookfield police, said he was a cat facing charges',
#  'epa urges flint residents to stop dumping tap water down drain',
#  'deepest ever dive finds plastic bag at bottom of mariana trench',
#  'narrow gaps in bathroom stall doors to be widened monday',
#  'study finds expressing anger in unhealthy ways actually incredibly satisfying',
#  "politics 2016 election congresswhite housejustice departmentnational securityelectionsfirst read politics mar 3 2016, 2:01 pm et christie on trump press conference flap: 'no, i was not being held hostage'",
#  'entire nation of new zealand unites against rowdy, drunken tourist family',
#  'new chinese suv has a hot japanese schoolgirl for holographic assistance',
#  "outrage over dog meat 'communion'",
#  'aides gently tell trump he cant bring all his gold lion statues on airplane',
#  'impressive new hire figures out bare minimum of work job requires on first day',
#  'new report finds u.s. employees most engaged at workplace while working as frontman of styx',
#  'this koch-backed group invites you to celebrate fossil fuels on earth day',
#  'heidi cruz responds to accusation her husband is the zodiac killer',
#  'this 82-year-old female powerlifter beat up a 28-year-old man who tried to break into her home',
#  'saudi arabia breads first female robot citizen',
#  'house wayans and means committee approves $50 million in funding for white chicks sequel',
#  'guard in video game under strict orders to repeatedly pace same stretch of hallway',
#  'dolphins fan starting to think brian flores not chief architect of patriots success',
#  "china 'fake sanitary pads' scam sparks health concerns",
#  'trump supporters worried racist attacks against progressive democrats just talk',
#  'sweating, grunting mike pence straining to rapture himself before impeachment inquiry goes any further',
#  'handmade banner that football team runs through before game the closest high school comes to supporting arts',
#  'area man obsessed with knowing if kevin spacey asshole in real life',
#  'new ‘curses’ emerge from tut’s history-making tomb study',
#  'nervous maid of honor just stringing together random maya angelou quotes',
#  "hamas founder's grandson is christian, gay",
#  'great, daughter measuring self-worth against some 13-year-old named skyla now',
#  'pope leaves detailed instructions for taking care of holy spirit while he out of town',
#  'rest of nation to penn state: something is very wrong with all of you',
#  'realtor obligated to tell potential buyers about murder happening in basement',
#  "iguanas are falling out of trees in florida because it's so cold. please don't pick them up.",
#  'tokyo’s drone squad will deploy 10-foot drones armed with nets to police the sky',
#  'it appears that trump may have just falsely accused himself of wiretapping himself',
#  'ben roethlisberger assures women of pittsburgh he not done yet',
#  "florida man charged after he's found with ecstasy pills shaped like donald trump's face",
#  'mueller tells trump hes not under criminal investigation',
#  'oklahoma "pastafarian" wears colander in license photo',
#  'ben carson: create palestinian state in egypt',
#  'new technology, new heroes!',
#  'engineers unveil new driverless car capable of committing hit-and-run',
#  'dad ready to forgive dixie chicks',
#  "black mp dawn butler 'mistaken for cleaner' in westminster",
#  "'selfie elbow' is actually a medical condition now",
#  'dirk nowitzki shatters backboard glass with powerful soprano singing voice',
#  'equifax ceo to congress: not sure we are encrypting data',
#  'man prowling at airport gate ready to pounce like jungle cat at first sign of boarding',
#  'dan savage disgusted by letter from perverted reader contemplating oral sex',
#  'nation horrified to discover cory booker already a senator',
#  'as firefighters rescue world series tickets from mission hills home, george brett appears',
#  'grandmother tackles man fleeing police, pulls his pants down',
#  'black mirror confirms we are not in an episode of black mirror.',
#  'i cant do this anymore, think 320 million americans quietly going about day',
#  'taxi driver just taking his time as if man not late for color me mine pottery party',
#  'billionaire reading name in panama papers totally forgot he even had funds in seychelles',
#  'newborn has fathers asshole',
#  'how facebook is slowly eating the rest of the internet',
#  'womans head feared lost forever inside infinity scarf',
#  'sheriffs officials respond to elf on the shelf’s body found in roadway',
#  'breaking: emergency room top potential landing spot for tony romo',
#  'meth addicts demand government address nations growing spider menace',
#  'congressman couldve sworn last impeachment was catered',
#  'multiple people injured in new york city building explosion',
#  'world rejoices as grumpy cat and her shitty attitude dead forever',
#  'cop vows to get revenge on eric garner for trying to frame him for murder',
#  'a 60 year old australian won a ultra marathon, 875 kilometers long.',
#  "utah threatens liquor permit of theater showing 'deadpool'",
#  'opening soon: gun range with a bar',
#  'company is offering ‘fur-ternity leave’ for new pet owners',
#  'hope hicks instructed to clean up all the evidence in her office before leaving',
#  'holiday gift guide for kids',
#  'you did the best you could, says iron man action figure voiced by despondent toys r us ceo packing up office',
#  "this entire article refers to this coming week's weather forecast in the past tense.",
#  'mlb recommends teams limit amount of screen time for rookies',
#  'hamblen county sheriff offers to inspect bad meth',
#  'man already knows everything he needs to know about muslims',
#  'gucci shuns glamour and sex for philosophy and severed heads',
#  'don’t vape, don’t juul says juul ceo',
#  'shreddies underwear hides your farts with science',
#  'iowan comforts sobbing jeb bush at town hall',
#  "after declaring 'public health crisis,' lawmaker wants to pave way for pornography lawsuits",
#  "'what's it like working with mexican drug cartels?' banking giant jpmorgan cancels twitter q&amp;a after thousands of abusive tweets",
#  'motorcyclist salvaged for parts',
#  'assault rifle in iraq losing track of how many times its switched sides during war',
#  'christmas comes early to venezuela, by presidential decree',
#  'hunters kill 2 moose, realize they are inside zoo',
#  'congress reaches tentative deal for border security deal',
#  'caitlyn jenner considering ‘de-transitioning’ ‘in the next couple years,’ author claims',
#  'new smithsonian exhibit details how fashion pioneers tamed the frumpy west',
#  "bay area coffee shop won't serve police for 'safety of customers'",
#  'frustrated man forced to agree with dumbass political cartoon of statue of liberty hugging immigrants',
#  'record number died in opioid epidemic in 2017',
#  "founder of white people meet hits back at claims of racism: 'i dated a black woman once'",
#  "santa claus's tomb may have been uncovered beneath turkish church",
#  'fda launches food awareness month to get americans interested in eating',
#  'goat of duty is call of duty but with goats',
#  'fire truck destroyed in blaze at fire station',
#  'packers’ rodgers impresses as scout team qb',
#  'free choco pies for life for north korean soldier defector',
#  '6 times sean penn inserted himself into world affairs',
#  "drive-by yoghurt attack on crochet teacher's haberdashery leaves her shaken read more at http://www.northdevonjournal.co.uk/drive-yoghurt-attack-crochet-teacher-s/story-28598609-detail/story.html#du3qw9kprg1gdtiv.99",
#  'womans primal instincts activate to protect nearly finished glass of wine from approaching server',
#  'middle couch cushion has clearly had harder life',
#  'cam newton was hacked because he had the worst twitter password ever',
#  "north seattle homeowners start neighborhood watch over 'serial pooper'",
#  'trump casually mills about supreme court changing rooms ahead of state of the union address',
#  'hobby lobby surrenders hundreds of additional smuggled iraq religious artifacts',
#  'the week in pictures – week of january 21, 2019',
#  'irs employee whose job was assisting victims of identity theft charged in $1 million identity theft tax fraud',
#  'i-90 adds lane for drivers traveling cross-country to stop woman from marrying wrong man',
#  "cia didn't always know who it was killing in drone strikes, classified documents show",
#  'zoo experiment shows porn puts pandas in the mood too.',
#  'popular new exercise app just tells users they ran 5 miles a day no matter what',
#  'trump is now greeting people with ‘no collusion’ instead of hello',
#  'dermatologists recommend regularly checking body for screaming demonic face bulging out of skin',
#  'newly redesigned hillaryclinton.com allows users to fully customize issues page to suit own preferences',
#  'a man fell into a gaping black hole at an art museum he thought was a piece of artwork',
#  "nbc declares rio a 'media' success, though tv ratings were down",
#  'nigerian billionare needs help',
#  'lawsuit: man refuses to show receipt at costco exit, employee breaks man’s leg',
#  'new ice agent establishes dominance by beating up biggest child prisoner on first day',
#  'real life magic school bus flies through human body',
#  'stock market plunges ahead of social hague trial',
#  'saudi arabia and iran accuse each other of not really being muslim',
#  'for sale: former prison with mountain view, sleeps hundreds',
#  'man keeps having same experience where he shows up to work naked',
#  'denied jaguar, haryana youth pushes bmw into river',
#  'prince fielder explains complexities of salary arbitration using cheeseburgers',
#  'heritage foundation lowers another retired gop senator into vat of strategists',
#  'chinese factory worker cant believe the shit he makes for americans',
#  'gop leaders demand congressman duncan hunters resignation after discovering he poor',
#  'how will immigration change under trump?',
#  '5 things to know about matthew whitaker',
#  'jaden smith writing book on philosophy',
#  'a 10-year-old named clark kent beat a record that michael phelps held for 23 years',
#  "india's monkeys 'to be put on the pill'",
#  'nothing is more attractive than confidence, says woman who has apparently never seen sonic the hedgehog cosplay',
#  'man smokes crack while hooked to oxygen mask, nearly burns down hospital',
#  'tv ad puppets electrify israeli gay rights debate',
#  "women's prison escapees caught at edmonton escape room",
#  "nebraska principal reportedly bans candy canes, says 'j shape' stands for jesus",
#  'area man accepts burden of being only person on earth who understands how world actually works',
#  'pat patriot denies being mascot #5 in prostitution sting police report',
#  'rex tillerson blindsided by news he still worked for state department',
#  'sydney couple wake to find naked irishman in their bed',
#  'virginia governor orders state of emergency ahead of unite the right anniversary',
#  'mattel releases new male barbie to inspire girls to imagine holding highest leadership positions',
#  "'game players fight giant space war'",
#  'parasitic space worm controlling mark kellys body announces arizona senate bid',
#  'donald trump puts key district in 12-year-old hands',
#  'man thanks god hes not sexually attracted to children',
#  'majority whip displays impaled senator outside capitol building as warning to all who cross party lines',
#  '[no] growing conspiracy on facebook claims nfc stickers on smartphone batteries are government surveillance devices',
#  'starbucks to close 8,000 stores for racial bias training',
#  'de blasio pac spends $30 million on ads urging candidate not to embarrass self by running',
#  'tila tequila sparks outrage by dressing her daughter as #babyhitler',
#  'boss makes lipstick prints on paychecks for valentines day',
#  'fingernail got fucking huge out of nowhere',
#  'mom scared for nhl players without visors',
#  "brain imaging scans reveal unusual 3-inch air pocket inside man's head",
#  "car explodes after driver sprays 'excessive' amount of air freshener before lighting cigarette",
#  "trump's advice to younger self: 'don't run for president'",
#  'susan rice: nsa officials didn’t lie, they ‘inadvertently made false representations’',
#  'spurs skype in kawhi leonard for game 4',
#  'should the browns use the first overall pick on a once-in-a-generation long snapper?',
#  'nazi-bred cows are too ferocious to farm',
#  "syrians babies called 'putin' in honour of russian president",
#  "ipad game nearly derailed kansas city royals' magical season",
#  "the maker of marlboro took out a full-page ad saying its new year's resolution is to 'give up cigarettes'",
#  'blacksburg man gets year for stalking women who cut him off in traffic',
#  'new york times rehires judith miller to cover escalating iran tensions',
#  'trump golfs with kid rock in florida, one day after mueller finishes russia probe',
#  "kanye west showers ben carson with praise: 'this is the most brilliant guy'",
#  'sanders campaign headquarters smashed up by gang of pinkerton union busters',
#  'cathedral’s tap-and-go collection payments divide congregation',
#  'woman confident she has the safety net it takes to achieve dreams',
#  'this turkey with two gay dads is the hero of thanksgiving 2017',
#  'noaa lowers warnings for atlantic hurricane season',
#  'ferguson judge withdraws all arrest warrants before 2015',
#  'kenyan lawyer sues israel, italy for killing jesus',
#  'as more young americans are using birth control, teen births have hit a new record low',
#  'obamas embarrassing ska album resurfaces',
#  'kim jong un wants north korea to host world cup despite crippling poverty',
#  'monkeys kill 72-year-old with shower of stolen bricks',
#  'will new nfl player safety rules ruin football injuries?',
#  'trump struggling to recall words to u.s.a. chant',
#  'trump’s ‘marching orders’ to the pentagon: plan a grand military parade',
#  'man regrets straying from sour cream and potato chips',
#  'report: sky normal today',
#  'u.s.-backed forces in syria begin attack on final isis encampment',
#  "man caught drinking bailey's irish cream jailed for 'acting like a homosexual'.",
#  'man surprised to learn high school classmate became completely different type of fuckup',
#  'trump in possible trouble for tweets',
#  'teens getting hurt playing fire challenge game',
#  'area dad stares longingly at covered grill in backyard',
#  'tampa bay lightning maintain home advantage by restricting admission to fans weighing 300 pounds or less',
#  'empty about us page leaves chinese buffets origins shrouded in mystery',
#  'a feces flinging female was detained in british colombia nsfw',
# ...
#  'campbells unveils new tomato soup humidifier',
#  'scouts highly doubtful tim tebow will ever make it to heaven',
#  'german, who claims to be "king of germany", gives back his official drivers license and makes out his own issued by "kingdom of germany". gets 7 months in jail for driving without a license.',
#  'american mormon is injured in his third brush with terrorism in brussels after surviving the boston bombing and the paris attacks',
#  'societal collapse narrowly averted after man honks horn at car paused at green light',
#  'god angrily clarifies dont kill rule',
#  "world's longest-surviving castaway sued for $1 million after being accused of 'eating his colleague'",
#  'boss really getting on mans ass about finishing ncaa bracket',
#  '"what a weird new way to be cheap and rude simultaneously" man\'s tipping method goes viral',
#  'father murders daughter and her boyfriend in ‘honour killing’ in pakistan but goes free after pardoning himself and his accomplices',
#  'trump rolls back michelle obama’s school lunch nutrition rules on her birthday.',
#  'empire state building files $1-million lawsuit against photographer over topless photos',
#  'miscalculating contestant rushes to cross out fuck alex trebek final jeopardy answer after seeing goodwill from previous contestant',
#  'biden kicked out of laundromat after shag rug floods washing machine',
#  'morocco tears down holocaust memorial after protesters said normalized relations with israel',
#  'nation allows itself 5 minutes to believe this all going to be over soon',
#  'breaking bad movie in the works',
#  'survey finds many gamers never finished red dead redemption 2',
#  'residents of philadelphia, cleveland at least relieved they cant host another one of these fucking things for few decades',
#  'man falls 70 feet into active volcano after climbing over metal railing to get a closer look',
#  'man legally changes his name to bacon double cheeseburger, fiancée unsurprisingly not impressed.',
#  "isu apologises after nominating 'offensive' auschwitz uniform for costume of year",
#  'police find stolen doughnut van, share treats with homeless',
#  'man parallel parking tries to leave enough room between cars to infuriate other drivers into just giving up',
#  'shit falls from sky ruins sweet 16 party and lands on birthday girl',
#  'trump boys forge fathers signature on letters they wrote excusing them from any more testifying',
#  "dogs drive owner's car into west virginia walmart",
#  'delta pilot refuses to land until gun control legislation passed',
#  'facebook declares mark zuckerberg dead',
#  'antarctica was just declared ‘the world’s first lgbt-friendly continent’',
#  'purina debuts new slovenly feast for nasty-ass shelter cats',
#  '5 things to know about neil gorsuch',
#  "zara's 'holocaust uniform' and other clothing errors",
#  'dad arrested for throwing daughter playboy-themed 18th birthday party',
#  'come fry with me',
#  'mother proud she raised type of person no one would ever believe would rape someone',
#  'man does incredibly well at slot machine demo embedded in ad',
#  '50% of georgia trump voters think hillary clinton had some involvement in the death of vince foster',
#  'people apparently been using rest stop barbecue pit',
#  'man shoots self in penis with girlfriend’s pink pistol, charges possible',
#  'high-ranking priest caught in cocaine-fueled gay orgy in vatican apartment',
#  'north, south korea in talks to announce end to 68-year korean war',
#  'guy accidentally hits ‘masturbate mode’ on his fake arm during tv interview',
#  'schumer introduces measure to decriminalize marijuana',
#  'taliban appeals to american people to ‘rationally’ rethink war effort',
#  'people in open-concept homes are realizing the walls were there for a reason',
#  'nike unveils size-inclusive mannequin eating a 12-inch hoagie',
#  'holy crap! frisco’s 16,000 stool fecal fiasco',
#  'mizzou protesters, black lives matter complain paris attacks stole their headlines',
#  'long john silvers introduces new golden fried abomination from the deep',
#  'a fish tale: local dog and koi fish form unlikely bond',
#  'health experts urge parents to dramatically reduce childrens on-screen time',
#  'how companies are going green',
#  'report: dad wants to show you where fuse box is',
#  'man starting to think only reason people hanging out with him because they all on same jury',
#  'nation rallies around ronald mcdonald statue that embodies countrys true heritage',
#  'sean hannity informs building tenants about deep-state conspiracy forcing him to triple rent',
#  'always to remove female symbol from sanitary products packaging',
#  'mothers day card finally arrives',
#  'risky choice: n.w.t. woman used bear to shake stalking wolf in 12-hour ordeal',
#  'minecraft developer teases character model update with three-pixel arms',
#  '5 things to know about milo yiannopoulos',
#  'volkswagen overstated fuel economy on 98k u.s. vehicles, will reimburse consumers',
#  'area woman lovingly lint rolling cardigan as if tending to prized stallion',
#  'trump promises government will continue to fund all essential mar-a-lago staff during shutdown',
#  'woman sues owners of dog killed by her pit bulls',
#  'tommy wiseau has officially announced a 3d version of the room',
#  'reddit users just discovered an incredibly obvious meal prep hack',
#  'tips for dealing with workplace burnout',
#  'french soldiers robbed of assault rifles &amp; ammo in mcdonald’s parking lot',
#  'trump aides investigating whistleblower struggling to identify single person in cia with moral principles',
#  'cool or creepy? walmart to deliver food and put it in fridge.',
#  'report: this movie old enough that they might have actually hurt dog',
#  'oriflame продукция для женщин зарегистрировавшись в системе вы самостоятельно сможете приобретать товар через интернет со скидкой 18% от цены указанной в красном прямоугольнике. регистрация тут http://oriflame7283.blogspot.ru/',
#  'jon bon jovi jealous of former classmate who made it out of jersey',
#  '11 government employees quit after election of first woman mayor in fundamentalist mormon city',
#  'jihad matchmaker is here to link up those seeking marriage in syria in a halal manner.',
#  'why are kate middleton’s fingers all the same length?',
#  'hundreds of blind, pallid disney characters discovered living in caves deep within space mountain',
#  'precocious 5-year-old already holding long, pointless business meeting with stuffed animals',
#  '12% of federal government thats currently functioning to shut down',
#  'n. korean leader complains about weather service',
#  'apologetic justin timberlake presents jessica biel with severed hand of alisha wainwright to prove loyalty',
#  '$30 million donation from chan-zuckerberg charity to help kids learn to read returned',
#  'rob ford vs. marion barry: who said it best?',
#  'furious meghan markle cant believe harry hasnt told family shes black yet',
#  'well be moving shortly, says train conductor waiting for workers to remove dead body from tracks',
#  "the ukrainian navy's combat dolphins, based in sevastopol, abruptly defected from the ukraine and switched sides to russia. they may face their american equivalents in the black sea as tensions between the west and russia heat up.",
#  'decision to circle parking lot produces carbon emission that finally does it',
#  'isis creates "suicide-chicken-bomb"',
#  'scientists genetically engineer lab rat predisposed to think anything wrong with it might be cancer',
#  'startup had ‘masturbation’ zone, exec who took off pants in meeting: lawsuit',
#  'loaded gun pulled from woman’s body cavity during drug bust',
#  'report: gross-ass gourd all bumpy and shit',
#  "baby poo sausages 'tasty', 'key to good gut'",
#  'kim kardashian in talks with jared kushner about pardon for a great-grandma',
#  "niagara falls is turning green this weekend in honor of st. patrick's day",
#  'goose hunter knocked unconscious by dead bird falling from sky',
#  "salem harassment trials: witch sues warlock over 'abuse and intimidation'",
#  'bosnian migrant blows up his ex-girlfriend with a hand grenade after she ran off with another man',
#  'a neo-nazi converted to islam and killed 2 roommates for ‘disrespecting’ his faith, police say',
#  'lego batman movie criticised as “pro-gay propaganda” by conservative blog',
#  'man arrested after selling farts in jars without a vending license',
#  'drunken man careens wildly across internet',
#  'when i need strength, i turn to the bible or whatever else is around',
#  'learn to toss pizza dough, or face deportation.',
#  'tinders parent company suing bumble for patent infringement',
#  'man whos only halfway through life can already guess how its going to end',
#  'my new job is eating pancakes in bed for nasa',
#  "cops raid german bloke’s house after his alexa music device 'held a party on its own' while he was out",
#  "cocaine in the river thames is 'another problem eels don't need', says expert",
#  'snoop dogg claims he smoked weed while doing ‘no. 2′ in white house',
#  'sf-based porn company offers sex-ed classes with live-demonstrations',
#  "police close off british main road to search for a man's lost penis",
#  'marco rubio would like to have a beer with devout muslim teenager malala yousafzai',
#  'mike pence is beginning to suspect from context clues that donald trump has never read the bible',
#  'christian bale loses 40 years for upcoming movie role',
#  'usda to stop referring to small raisins as ‘midgets’',
#  'newly unemployed woman enjoys equal pay for first time in career',
#  'nra touts oliver norths expertise at avoiding jail time for colluding with hostile foreign powers',
#  'roommates work schedule remains complete and total mystery',
#  'female presidential candidate who was united states senator, secretary of state told to be more inspiring',
#  "poo found on every mcdonold's touch screen tested",
#  "'fake doctor' shyam acharya well known for lack of medical knowledge, former colleague claims",
#  'nik&amp;jay - gimigdinetanker unstable mix',
#  'centipedes: you know what to do...',
#  'mysterious crate arrives from london',
#  'ron paul elected ruler of planet inhabited by 1 billion tiny ron pauls',
#  'over the river and void of goods',
#  'floating heap of trash now oceans apex predator',
#  'great occasion to sneak a pun in, nytimes. geez',
#  'dead woman hanging from fence mistaken for halloween display',
#  "nebraska flag flew upside down at capitol for 10 days and 'nobody noticed,' says senator who wants design change",
#  'fearful americans stockpiling facts before federal government comes to take them away.',
#  'first national fire hydrant toss event held in aargau',
#  'chinese astronomers inform beijing residents sky will be visible for rare 2-minute window tomorrow morning',
#  'ted cruz heckled out of d.c. restaurant',
#  'nutritionists report they wouldnt have to figure out which foods were bad for you if americans just ate normal for once',
#  'mark mcgwire claims he would have hit 70 home runs without help of bat',
#  "air force dogfight exercise accidentally formed 'sky penis,' officials say",
#  'best method of finding job still excitedly circling newspaper listing in red marker',
#  'notre dame gargoyle going to stay as still as possible until arson investigator gone',
#  'fda approves female-libido-enhancing man',
#  'brain surgery performed on wrong patient at kenyan hospital',
#  'portsmouth v southampton: horse punched by fan amid disorder',
#  'hài tết 2016 anh chồng yếu sinh lý',
#  'child firing uzi at ariz. shooting range accidentally kills instructor, police say',
#  '8chan, popular message board for mass shooters, goes dark',
#  'worlds leading scientists nervously stand next to poster-board displays as nobel committee walks through gymnasium',
#  'sinkhole large enough to swallow a car, or two, in detroit',
#  'home invasion suspect to praying victim: ‘i believe in jesus, too’',
#  'chuck grassley reveals he voted against mlk day due to foreseeing how everyone would dishonor his memory',
#  'heavy metal makes you calmer, say researchers',
#  'god getting strong urge to bring back dinosaurs',
#  'ban on ‘small screaming children’ puts cape breton restaurant at centre of tug-of-war over dining etiquette',
#  'man incarcerated after attempting to break into allegheny county jail',
#  'trump agrees to wear wire to take down roger stone',
#  "watch 'msg the warrior - lion heart' trailer: dera sacha sauda chief battles aliens in his latest film [video]",
#  'illinois lawmaker files bill to crack down on pokemon go',
#  'exorcism rituals on the rise as way to battle evil of mexican cartels',
#  'new parenting trend involves just handing children bulleted list of things to accomplish by 30',
#  '74 year old sues mcdonalds for scalding hot coffee causing “severe burning to her genitalia,”',
#  'report: getting out of bed in morning sharply increases risk of things getting even worse',
#  'family figures grandpa never talks about wwii because nothing interesting happened to him',
#  'touching tribute: nintendo is finally adding a grass-type pokémon based on james gandolfini',
#  "can't believe this is real",
#  'judge jails kids for refusing lunch with dad',
#  '100% chance of penis in latest noaa hurricane walaka map',
#  "woman gets stuck upside down in 'tinder date's window trying to retrieve her poo' until firefighters save her",
#  'dasani under fire after tanker explosion leads to massive water spill off coast of mexico',
#  'naked off—duty police officer arrests sweaty suspect in swedish sauna',
#  'necessary? bar garnishes bloody mary with entire fried chicken.',
#  'man takes ax to family car and tv because he thought wife damaged action figures.',
#  'measles cases at highest for 20 years in europe, as anti-vaccine movement grows',
#  'kevin bacon, the pig, returned home after romp around halifax',
#  'report: white house officials deliberately hid fdrs mechanical spider legs from public',
#  'scientists create man-pig embryo',
#  'cows don’t have fingers and can’t insult devin nunes on twitter, court filing says',
#  'aol still has 2 million customers paying for dial up',
#  'exhausted nation unsure it has stamina to continue gun control dialogue for fifth consecutive day',
#  'selfish missouri voters reject anti-union law after everything bosses have done for them',
#  'lifelong love affair with music ends at age 35',
#  'optometrist sets pressure of air puff test way higher for asshole patients',
#  'taco bell employee refuses to serve customer who doesn’t speak spanish',
#  'turkey testicle festival host not ruffled by competing event',
#  'man who ordered child-sized sex doll tells court it was to replace dead infant son',
#  'man tried to rob salon but was spotted by local and beaten with yankee candle',
#  "white house not tamping down tensions after bolton seen holding notepad with words '5000 troops to colombia'",
#  'facebook finds that not all users want to review their year',
#  'kanye west announces 2020 presidential run',
#  "driver that struck teen suing dead boy's family",
#  '19-year-old anti-gun violence activist shot and killed in chicago',
#  'oxiclean unveils new stain-removing fabric scissors',
#  'astrologer claiming he predicted past tragedies, says eclipse will bring another',
#  'the white house actually sought a cost estimate for trump’s alligator-filled border moat, officials say',
#  'old state department library now consists of nothing but donald trump books',
#  'republican congressman says white terrorists are different',
#  'report: a lot of peoples dream is to have sex with a ghost',
#  '30-million-year-old species worried it doesnt have another evolution in it',
#  'former nba guard delonte west denies he is homeless; says he was helping homeless people',
#  'area man nostalgic for time when ads targeting him not as sad',
#  'solo: a star wars story producer points out all the cameos made by the films kickstarter donors',
#  'study finds earths animals one giant creature before breaking apart millions of years ago',
#  "husband tells wife 'it's me or the dogs!' wife chooses dogs, ends 25-year marriage",
#  ...]

# %%
display(pipe.score(X_train.map(lambda x: nlp_lg(x)), y_train))
display(pipe.score(X_test.map(lambda x: nlp_lg(x)), y_test))
display(pipe.score(theonion_holdout["title"].map(lambda x: nlp_lg(x)), theonion_holdout["is_onion"]))
display(pipe.score(nottheonion_holdout["title"].map(lambda x: nlp_lg(x)), nottheonion_holdout["is_onion"]))
